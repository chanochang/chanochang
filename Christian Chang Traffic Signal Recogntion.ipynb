# %%
import pandas as pd

# %%
f = ../TLD/dataset_train_riib
# Out:
#   File "C:\Users\chano\AppData\Local\Temp\ipykernel_232\2619051947.py", line 1
#     f = ../TLD/dataset_train_riib
#         ^
# SyntaxError: invalid syntax

# %%
f = train.yml
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_232\4145980410.py in <module>
# ----> 1 f = train.yml
#
# NameError: name 'train' is not defined

# %%
from skimage import io
import os
import glob


def get_class(img_path):
    return int(img_path.split('\\')[-2])

root_dir = 'GTSRB/Final_Training/Images/'
imgs = []
labels = []

all_img_paths = glob.glob(os.path.join(root_dir, '*/*.ppm'))
np.random.shuffle(all_img_paths)
for img_path in all_img_paths:
    img = preprocess_img(io.imread(img_path))
    label = get_class(img_path)
    imgs.append(img)
    labels.append(label)

X = np.array(imgs, dtype='float32')
# Make one hot targets
Y = np.eye(NUM_CLASSES, dtype='uint8')[labels]

# %%
f = 'train.yml'

# %%
pd.io.json.json_normalize(yaml.load(f), 'boxes', 'path')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_232\3792051206.py in <module>
# ----> 1 pd.io.json.json_normalize(yaml.load(f), 'boxes', 'path')
#
# NameError: name 'yaml' is not defined

# %%
from pandas import json_normalize
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_232\3424751567.py in <module>
# ----> 1 from pandas import json_normalize
#
# ImportError: cannot import name 'json_normalize' from 'pandas' (D:\Users\chano\Anaconda2\envs\tf-gpu\lib\site-packages\pandas\__init__.py)

# %%
import pandas as pd

# %%
from pandas import json_normalize
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_232\3424751567.py in <module>
# ----> 1 from pandas import json_normalize
#
# ImportError: cannot import name 'json_normalize' from 'pandas' (D:\Users\chano\Anaconda2\envs\tf-gpu\lib\site-packages\pandas\__init__.py)

# %%
import yaml

# %%
pd.io.json.json_normalize(yaml.load(f), 'boxes', 'path')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_232\3792051206.py in <module>
# ----> 1 pd.io.json.json_normalize(yaml.load(f), 'boxes', 'path')
#
# TypeError: load() missing 1 required positional argument: 'Loader'

# %%
pd.io.json.json_normalize(yaml.load(f), 'boxes', 'path')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_232\3792051206.py in <module>
# ----> 1 pd.io.json.json_normalize(yaml.load(f), 'boxes', 'path')
#
# TypeError: load() missing 1 required positional argument: 'Loader'

# %%
from yaml import SafeLoader, load

# %%
pd.io.json.json_normalize(yaml.load(f), 'boxes', 'path')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_232\3792051206.py in <module>
# ----> 1 pd.io.json.json_normalize(yaml.load(f), 'boxes', 'path')
#
# TypeError: load() missing 1 required positional argument: 'Loader'

# %%
with open('train.yaml', 'r') as f:
    df = pd.json_normalize(safe_load(f))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_232\2044508415.py in <module>
# ----> 1 with open('train.yaml', 'r') as f:
#       2     df = pd.json_normalize(safe_load(f))
#
# FileNotFoundError: [Errno 2] No such file or directory: 'train.yaml'

# %%
f
# Out:
# 'train.yml'

# %%
with open('train.yaml', 'r') as f:
    df = pd.json_normalize(safe_load(f))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_232\2044508415.py in <module>
# ----> 1 with open('train.yaml', 'r') as f:
#       2     df = pd.json_normalize(safe_load(f))
#
# FileNotFoundError: [Errno 2] No such file or directory: 'train.yaml'

# %%
with open("train.yaml", 'r') as f:
    df = pd.json_normalize(safe_load(f))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_232\3864935985.py in <module>
# ----> 1 with open("train.yaml", 'r') as f:
#       2     df = pd.json_normalize(safe_load(f))
#
# FileNotFoundError: [Errno 2] No such file or directory: 'train.yaml'

# %%
with open('train.yaml', 'r') as f:
    df = pd.json_normalize(safe_load(f))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_232\2044508415.py in <module>
# ----> 1 with open('train.yaml', 'r') as f:
#       2     df = pd.json_normalize(safe_load(f))
#
# FileNotFoundError: [Errno 2] No such file or directory: 'train.yaml'

# %%
df = pd.json_normalize(safe_load(f))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_232\3962329882.py in <module>
# ----> 1 df = pd.json_normalize(safe_load(f))
#
# D:\Users\chano\Anaconda2\envs\tf-gpu\lib\site-packages\pandas\__init__.py in __getattr__(name)
#     212
#     213             return Panel
# --> 214         raise AttributeError("module 'pandas' has no attribute '{}'".format(name))
#     215
#     216
#
# AttributeError: module 'pandas' has no attribute 'json_normalize'

# %%
df = pd.json_normalize(yaml.safe_load(f))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_232\448281918.py in <module>
# ----> 1 df = pd.json_normalize(yaml.safe_load(f))
#
# D:\Users\chano\Anaconda2\envs\tf-gpu\lib\site-packages\pandas\__init__.py in __getattr__(name)
#     212
#     213             return Panel
# --> 214         raise AttributeError("module 'pandas' has no attribute '{}'".format(name))
#     215
#     216
#
# AttributeError: module 'pandas' has no attribute 'json_normalize'

# %%
 yaml_contents = load(f, Loader=SafeLoader)
yaml_df = json_normalize(yaml_contents)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_232\3119150071.py in <module>
#       1 yaml_contents = load(f, Loader=SafeLoader)
# ----> 2 yaml_df = json_normalize(yaml_contents)
#
# NameError: name 'json_normalize' is not defined

# %%
from pandas import json_normalize
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_232\3424751567.py in <module>
# ----> 1 from pandas import json_normalize
#
# ImportError: cannot import name 'json_normalize' from 'pandas' (D:\Users\chano\Anaconda2\envs\tf-gpu\lib\site-packages\pandas\__init__.py)

# %%
with open('train.yaml', 'r') as f:
    df = pd.io.json.json_normalize(yaml.load(f))

df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_232\3565376856.py in <module>
# ----> 1 with open('train.yaml', 'r') as f:
#       2     df = pd.io.json.json_normalize(yaml.load(f))
#       3
#       4 df.head()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'train.yaml'

# %%
with open('train.yaml', 'r') as f:
    df = pd.json_normalize(safe_load(f))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_232\2044508415.py in <module>
# ----> 1 with open('train.yaml', 'r') as f:
#       2     df = pd.json_normalize(safe_load(f))
#
# FileNotFoundError: [Errno 2] No such file or directory: 'train.yaml'

# %%
file = 'train.yaml'

# Begin assignment
path = "./"

f = os.path.join(path,file)
#df = pd.read_csv(filename_read)
with open('train.yaml', 'r') as f:
    df = pd.json_normalize(safe_load(f))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_232\2223129104.py in <module>
#       4 path = "./"
#       5
# ----> 6 f = os.path.join(path,file)
#       7 #df = pd.read_csv(filename_read)
#       8 with open('train.yaml', 'r') as f:
#
# NameError: name 'os' is not defined

# %%
import os

# %%
file = 'train.yaml'

# Begin assignment
path = "./"

f = os.path.join(path,file)
#df = pd.read_csv(filename_read)
with open('train.yaml', 'r') as f:
    df = pd.json_normalize(safe_load(f))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_232\2223129104.py in <module>
#       6 f = os.path.join(path,file)
#       7 #df = pd.read_csv(filename_read)
# ----> 8 with open('train.yaml', 'r') as f:
#       9     df = pd.json_normalize(safe_load(f))
#
# FileNotFoundError: [Errno 2] No such file or directory: 'train.yaml'

# %%
file = "train.yaml"

# Begin assignment
path = "./"

f = os.path.join(path,file)
#df = pd.read_csv(filename_read)
df = pd.json_normalize(safe_load(f))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_232\2718170641.py in <module>
#       6 f = os.path.join(path,file)
#       7 #df = pd.read_csv(filename_read)
# ----> 8 df = pd.json_normalize(safe_load(f))
#
# D:\Users\chano\Anaconda2\envs\tf-gpu\lib\site-packages\pandas\__init__.py in __getattr__(name)
#     212
#     213             return Panel
# --> 214         raise AttributeError("module 'pandas' has no attribute '{}'".format(name))
#     215
#     216
#
# AttributeError: module 'pandas' has no attribute 'json_normalize'

# %%
a_yaml_file = open("train.yaml")

parsed_yaml_file = yaml.load(a_yaml_file, Loader=yaml.FullLoader)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_232\1733501968.py in <module>
# ----> 1 a_yaml_file = open("train.yaml")
#       2
#       3 parsed_yaml_file = yaml.load(a_yaml_file, Loader=yaml.FullLoader)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'train.yaml'

# %%
a_yaml_file = open("train.yaml")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_232\3408094582.py in <module>
# ----> 1 a_yaml_file = open("train.yaml")
#
# FileNotFoundError: [Errno 2] No such file or directory: 'train.yaml'

# %%
file
# Out:
# 'train.yaml'

# %%
path = "./"

f = os.path.join(path,file)

# %%
f
# Out:
# './train.yaml'

# %%
a_yaml_file = open("train.yaml")

# %%
parsed_yaml_file = yaml.load(a_yaml_file, Loader=yaml.FullLoader)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_31612\1242315558.py in <module>
# ----> 1 parsed_yaml_file = yaml.load(a_yaml_file, Loader=yaml.FullLoader)
#
# NameError: name 'yaml' is not defined

# %%
import yaml
import pandas as pd

# %%
parsed_yaml_file = yaml.load(a_yaml_file, Loader=yaml.FullLoader)

# %%
parsed_yaml_file
# Out:
# [{'boxes': [],
#   'path': './rgb/train/2017-02-03-11-44-56_los_altos_mountain_view_traffic_lights_bag/207374.png'},
#  {'boxes': [],
#   'path': './rgb/train/2017-02-03-11-44-56_los_altos_mountain_view_traffic_lights_bag/207384.png'},
#  {'boxes': [{'label': 'Yellow',
#     'occluded': True,
#     'x_max': 615.75,
#     'x_min': 610.625,
#     'y_max': 358.625,
#     'y_min': 351.5},
#    {'label': 'Yellow',
#     'occluded': False,
#     'x_max': 638.125,
#     'x_min': 633.875,
#     'y_max': 351.0,
#     'y_min': 342.25},
#    {'label': 'Yellow',
#     'occluded': False,
#     'x_max': 655.0,
#     'x_min': 649.5,
#     'y_max': 360.75,
#     'y_min': 350.375}],
#   'path': './rgb/train/2017-02-03-11-44-56_los_altos_mountain_view_traffic_lights_bag/207386.png'},
#  {'boxes': [{'label': 'RedLeft',
#     'occluded': True,
#     'x_max': 615.5,
#     'x_min': 612.0,
#     'y_max': 360.375,
#     'y_min': 354.75},
#    {'label': 'Red',
#     'occluded': False,
# ...

# %%
with open('train.yaml', 'r') as f:
    df = pd.json_normalize(safe_load(f))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_31612\2044508415.py in <module>
#       1 with open('train.yaml', 'r') as f:
# ----> 2     df = pd.json_normalize(safe_load(f))
#
# D:\Users\chano\Anaconda2\envs\tf-gpu\lib\site-packages\pandas\__init__.py in __getattr__(name)
#     212
#     213             return Panel
# --> 214         raise AttributeError("module 'pandas' has no attribute '{}'".format(name))
#     215
#     216
#
# AttributeError: module 'pandas' has no attribute 'json_normalize'

# %%
 df = pd.json_normalize(safe_load(f))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_31612\3605942127.py in <module>
# ----> 1 df = pd.json_normalize(safe_load(f))
#
# D:\Users\chano\Anaconda2\envs\tf-gpu\lib\site-packages\pandas\__init__.py in __getattr__(name)
#     212
#     213             return Panel
# --> 214         raise AttributeError("module 'pandas' has no attribute '{}'".format(name))
#     215
#     216
#
# AttributeError: module 'pandas' has no attribute 'json_normalize'

# %%
 df = json_normalize(safe_load(f))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_31612\3221095072.py in <module>
# ----> 1 df = json_normalize(safe_load(f))
#
# NameError: name 'json_normalize' is not defined

# %%
from pandas import json_normalize
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_31612\3424751567.py in <module>
# ----> 1 from pandas import json_normalize
#
# ImportError: cannot import name 'json_normalize' from 'pandas' (D:\Users\chano\Anaconda2\envs\tf-gpu\lib\site-packages\pandas\__init__.py)

# %%
df = pd.io.json.json_normalize(yaml.load(f))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_31612\3548748622.py in <module>
# ----> 1 df = pd.io.json.json_normalize(yaml.load(f))
#
# TypeError: load() missing 1 required positional argument: 'Loader'

# %%
df = pd.io.json.json_normalize(yaml.load(f),Loader=yaml.FullLoader)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_31612\3280911701.py in <module>
# ----> 1 df = pd.io.json.json_normalize(yaml.load(f),Loader=yaml.FullLoader)
#
# TypeError: load() missing 1 required positional argument: 'Loader'

# %%
df = pd.io.json.json_normalize(yaml.load(f),Loader=SafeLoader)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_31612\1063957967.py in <module>
# ----> 1 df = pd.io.json.json_normalize(yaml.load(f),Loader=SafeLoader)
#
# TypeError: load() missing 1 required positional argument: 'Loader'

# %%
df = pd.io.json.json_normalize(yaml.load(f, Loader=yaml.FullLoader))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_31612\807740643.py in <module>
# ----> 1 df = pd.io.json.json_normalize(yaml.load(f, Loader=SafeLoader))
#
# NameError: name 'SafeLoader' is not defined

# %%
df = pd.io.json.json_normalize(yaml.load(f, Loader=yaml.FullLoader))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_31612\243959632.py in <module>
# ----> 1 df = pd.io.json.json_normalize(yaml.load(f, Loader=yaml.FullLoader))
#
# D:\Users\chano\Anaconda2\envs\tf-gpu\lib\site-packages\yaml\__init__.py in load(stream, Loader)
#      77     and produce the corresponding Python object.
#      78     """
# ---> 79     loader = Loader(stream)
#      80     try:
#      81         return loader.get_single_data()
#
# D:\Users\chano\Anaconda2\envs\tf-gpu\lib\site-packages\yaml\loader.py in __init__(self, stream)
#      22
#      23     def __init__(self, stream):
# ---> 24         Reader.__init__(self, stream)
#      25         Scanner.__init__(self)
#      26         Parser.__init__(self)
#
# D:\Users\chano\Anaconda2\envs\tf-gpu\lib\site-packages\yaml\reader.py in __init__(self, stream)
# ...

# %%
with open('train.yaml', 'r') as f:
    df = pd.io.json.json_normalize(yaml.load(f, Loader=yaml.FullLoader))

# %%
df
# Out:
#                                                   boxes  \
# 0                                                    []
# 1                                                    []
# 2     [{'label': 'Yellow', 'occluded': True, 'x_max'...
# 3     [{'label': 'RedLeft', 'occluded': True, 'x_max...
# 4     [{'label': 'RedLeft', 'occluded': False, 'x_ma...
# ...                                                 ...
# 5088  [{'label': 'Green', 'occluded': False, 'x_max'...
# 5089  [{'label': 'Green', 'occluded': False, 'x_max'...
# 5090  [{'label': 'Green', 'occluded': False, 'x_max'...
# 5091  [{'label': 'Green', 'occluded': False, 'x_max'...
# 5092                                                 []
#
#                                                    path
# 0     ./rgb/train/2017-02-03-11-44-56_los_altos_moun...
# 1     ./rgb/train/2017-02-03-11-44-56_los_altos_moun...
# 2     ./rgb/train/2017-02-03-11-44-56_los_altos_moun...
# 3     ./rgb/train/2017-02-03-11-44-56_los_altos_moun...
# ...

# %%
df('box')(1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_31612\2555153151.py in <module>
# ----> 1 df('box')(1)
#
# TypeError: 'DataFrame' object is not callable

# %%
df2 = pd.io.json.json_normalize(yaml.load(f), 'reviews', 'doc')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_31612\3724350930.py in <module>
# ----> 1 df2 = pd.io.json.json_normalize(yaml.load(f), 'reviews', 'doc')
#
# TypeError: load() missing 1 required positional argument: 'Loader'

# %%
with open('train.yaml', 'r') as f:
    df2 = pd.io.json.json_normalize(yaml.load(f, Loader=yaml.FullLoader),'boxes', 'path' )

# %%
with open('train.yaml', 'r') as f:
    df = pd.io.json.json_normalize(yaml.load(f, Loader=yaml.FullLoader),'boxes', 'path' )

# %%
df3
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_31612\1715873167.py in <module>
# ----> 1 df3
#
# NameError: name 'df3' is not defined

# %%
df2
# Out:
#          label  occluded       x_max       x_min       y_max       y_min  \
# 0       Yellow      True  615.750000  610.625000  358.625000  351.500000
# 1       Yellow     False  638.125000  633.875000  351.000000  342.250000
# 2       Yellow     False  655.000000  649.500000  360.750000  350.375000
# 3      RedLeft      True  615.500000  612.000000  360.375000  354.750000
# 4          Red     False  636.625000  632.250000  355.375000  346.375000
# ...        ...       ...         ...         ...         ...         ...
# 10751    Green     False  590.047547  573.580846  219.137754  175.765818
# 10752    Green     False  544.689352  508.938214   71.680937    1.331923
# 10753    Green     False  892.943457  861.151823  224.574408  154.392877
# 10754    Green     False  582.341789  573.372644  276.627118  256.311463
# 10755    Green     False  517.626782  510.027687  273.164089  256.427986
#
#                                                     path
# ...

# %%
df2.to_csv('train.csv',index=False)

# %%
import numpy as np
from skimage import color, exposure, transform

NUM_CLASSES = 4
IMG_SIZE = 48


def preprocess_img(img):
    # Histogram normalization in v channel
    #hsv = color.rgb2hsv(img)
    #hsv[:, :, 2] = exposure.equalize_hist(hsv[:, :, 2])
    #img = color.hsv2rgb(hsv)

    # central square crop
    min_side = min(img.shape[:-1])
    centre = img.shape[0] // 2, img.shape[1] // 2
    img = img[centre[0] - min_side // 2:centre[0] + min_side // 2,
              centre[1] - min_side // 2:centre[1] + min_side // 2,
              :]

    # rescale to standard size
    img = transform.resize(img, (IMG_SIZE, IMG_SIZE))

    # roll color axis to axis 0
    img = np.rollaxis(img, -1)

    return img
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_31612\2769921394.py in <module>
#       1 import numpy as np
# ----> 2 from skimage import color, exposure, transform
#       3
#       4 NUM_CLASSES = 4
#       5 IMG_SIZE = 48
#
# ModuleNotFoundError: No module named 'skimage'

# %%
import numpy as np
from skimage import color, exposure, transform

NUM_CLASSES = 4
IMG_SIZE = 48


def preprocess_img(img):
    # Histogram normalization in v channel
    #hsv = color.rgb2hsv(img)
    #hsv[:, :, 2] = exposure.equalize_hist(hsv[:, :, 2])
    #img = color.hsv2rgb(hsv)

    # central square crop
    min_side = min(img.shape[:-1])
    centre = img.shape[0] // 2, img.shape[1] // 2
    img = img[centre[0] - min_side // 2:centre[0] + min_side // 2,
              centre[1] - min_side // 2:centre[1] + min_side // 2,
              :]

    # rescale to standard size
    img = transform.resize(img, (IMG_SIZE, IMG_SIZE))

    # roll color axis to axis 0
    img = np.rollaxis(img, -1)

    return img

# %%
from skimage import io
import os
import glob


def get_class(img_path):
    return int(img_path.split('\\')[-2])

root_dir = 'GTSRB/Final_Training/Images/'
imgs = []
labels = []

all_img_paths = glob.glob(os.path.join(root_dir, '*/*.ppm'))
np.random.shuffle(all_img_paths)
for img_path in all_img_paths:
    img = preprocess_img(io.imread(img_path))
    label = get_class(img_path)
    imgs.append(img)
    labels.append(label)

X = np.array(imgs, dtype='float32')
# Make one hot targets
Y = np.eye(NUM_CLASSES, dtype='uint8')[labels]

# %%
root_dir = 'dataset_train_riib/riib/train/'
# Out:
#   File "C:\Users\chano\AppData\Local\Temp\ipykernel_11500\1439844198.py", line 1
#     root_dir = 'dataset_train_riib\riib\train\'
#                                                ^
# SyntaxError: EOL while scanning string literal

# %%
root_dir = 'dataset_train_riib/riib/train/'

# %%
all_img_paths = glob.glob(os.path.join(root_dir, '*/*.pgm'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11500\1723010308.py in <module>
# ----> 1 all_img_paths = glob.glob(os.path.join(root_dir, '*/*.pgm'))
#
# NameError: name 'glob' is not defined

# %%
import os
import glob
all_img_paths = glob.glob(os.path.join(root_dir, '*/*.pgm'))

# %%
all_img_paths
# Out:
# ['dataset_train_riib/riib/train\\2015-05-29-15-29-39_arastradero_traffic_light_loop_bag\\10648.pgm',
#  'dataset_train_riib/riib/train\\2015-05-29-15-29-39_arastradero_traffic_light_loop_bag\\10718.pgm',
#  'dataset_train_riib/riib/train\\2015-05-29-15-29-39_arastradero_traffic_light_loop_bag\\10786.pgm',
#  'dataset_train_riib/riib/train\\2015-05-29-15-29-39_arastradero_traffic_light_loop_bag\\10856.pgm',
#  'dataset_train_riib/riib/train\\2015-05-29-15-29-39_arastradero_traffic_light_loop_bag\\10926.pgm',
#  'dataset_train_riib/riib/train\\2015-05-29-15-29-39_arastradero_traffic_light_loop_bag\\10996.pgm',
#  'dataset_train_riib/riib/train\\2015-05-29-15-29-39_arastradero_traffic_light_loop_bag\\11064.pgm',
#  'dataset_train_riib/riib/train\\2015-05-29-15-29-39_arastradero_traffic_light_loop_bag\\11134.pgm',
#  'dataset_train_riib/riib/train\\2015-05-29-15-29-39_arastradero_traffic_light_loop_bag\\11204.pgm',
# ...

# %%
from skimage import io
import os
import glob


def get_class(img_path):
    return int(img_path.split('\\')[-2])

root_dir = 'dataset_train_riib/riib/train/'
imgs = []
labels = []

all_img_paths = glob.glob(os.path.join(root_dir, '*/*.pgm'))
np.random.shuffle(all_img_paths)
for img_path in all_img_paths:
    img = preprocess_img(io.imread(img_path))
    label = get_class(img_path)
    imgs.append(img)
    labels.append(label)

X = np.array(imgs, dtype='float32')
# Make one hot targets
Y = np.eye(NUM_CLASSES, dtype='uint8')[labels]

# %%
def preprocess_img(img):

    #img = rgb2gray(img)
    
    # thresholding and sobel filter
    #t = skimage.filters.threshold_otsu(img)
    #img = img > t

    #img = sobel_h(img)
    
    # top half crop
    #img = img[240:480,0:640]

    # downsample by 100
    img = rescale(img, scale=(0.1))
    
    # roll color to axis 0
    img = np.rollaxis(img, -1)

    return img

# %%
from skimage import io
import os
import glob


def get_class(img_path):
    return int(img_path.split('\\')[-2])

root_dir = 'dataset_train_riib/riib/train/'
imgs = []
labels = []

all_img_paths = glob.glob(os.path.join(root_dir, '*/*.pgm'))
np.random.shuffle(all_img_paths)
for img_path in all_img_paths:
    img = preprocess_img(io.imread(img_path))
    label = get_class(img_path)
    imgs.append(img)
    labels.append(label)

X = np.array(imgs, dtype='float32')
# Make one hot targets
Y = np.eye(NUM_CLASSES, dtype='uint8')[labels]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11500\163317988.py in <module>
#      14 np.random.shuffle(all_img_paths)
#      15 for img_path in all_img_paths:
# ---> 16     img = preprocess_img(io.imread(img_path))
#      17     label = get_class(img_path)
#      18     imgs.append(img)
#
# ~\AppData\Local\Temp\ipykernel_11500\2399427581.py in preprocess_img(img)
#      13
#      14     # downsample by 100
# ---> 15     img = rescale(img, scale=(0.1))
#      16
#      17     # roll color to axis 0
#
# NameError: name 'rescale' is not defined

# %%
import numpy as np
from skimage import color, exposure, transform 
import  skimage
from skimage.color import rgb2gray
from skimage.filters import sobel_h
import skimage.color
import skimage.filters
from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Activation, Flatten
from keras.layers.convolutional import Conv2D
from keras.layers.pooling import MaxPooling2D
from keras.optimizers import SGD
from keras import backend as K
K.set_image_data_format('channels_first')
from skimage.transform import rescale

from matplotlib.pyplot import figure, show
from sklearn.model_selection import train_test_split
import pandas as pd
import os
import numpy as np
from sklearn import metrics
from scipy.stats import zscore
import tensorflow as tf
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint
# Out:
# Using TensorFlow backend.

# %%
from skimage import io
import os
import glob


def get_class(img_path):
    return int(img_path.split('\\')[-2])

root_dir = 'dataset_train_riib/riib/train/'
imgs = []
labels = []

all_img_paths = glob.glob(os.path.join(root_dir, '*/*.pgm'))
np.random.shuffle(all_img_paths)
for img_path in all_img_paths:
    img = preprocess_img(io.imread(img_path))
    label = get_class(img_path)
    imgs.append(img)
    labels.append(label)

X = np.array(imgs, dtype='float32')
# Make one hot targets
Y = np.eye(NUM_CLASSES, dtype='uint8')[labels]
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "D:\Users\chano\Anaconda2\envs\tf-gpu\lib\site-packages\IPython\core\interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\chano\AppData\Local\Temp\ipykernel_11500\163317988.py", line 16, in <module>
#     img = preprocess_img(io.imread(img_path))
#   File "C:\Users\chano\AppData\Local\Temp\ipykernel_11500\2399427581.py", line 15, in preprocess_img
#     img = rescale(img, scale=(0.1))
# NameError: name 'rescale' is not defined
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
# ...

# %%
from skimage.transform import rescale
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session 216

# %%
from skimage import io
import os
import glob


def get_class(img_path):
    return int(img_path.split('\\')[-2])

root_dir = 'dataset_train_riib/riib/train/'
imgs = []
labels = []

all_img_paths = glob.glob(os.path.join(root_dir, '*/*.pgm'))
np.random.shuffle(all_img_paths)
for img_path in all_img_paths:
    img = preprocess_img(io.imread(img_path))
    label = get_class(img_path)
    imgs.append(img)
    labels.append(label)

X = np.array(imgs, dtype='float32')
# Make one hot targets
Y = np.eye(NUM_CLASSES, dtype='uint8')[labels]
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "D:\Users\chano\Anaconda2\envs\tf-gpu\lib\site-packages\IPython\core\interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\chano\AppData\Local\Temp\ipykernel_11500\163317988.py", line 17, in <module>
#     label = get_class(img_path)
#   File "C:\Users\chano\AppData\Local\Temp\ipykernel_11500\163317988.py", line 7, in get_class
#     return int(img_path.split('\\')[-2])
# ValueError: invalid literal for int() with base 10: '2015-10-05-10-52-01_bag'
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
import numpy as np
from skimage import color, exposure, transform 
import  skimage
from skimage.color import rgb2gray
from skimage.filters import sobel_h
import skimage.color
import skimage.filters
from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Activation, Flatten
from keras.layers.convolutional import Conv2D
from keras.layers.pooling import MaxPooling2D
from keras.optimizers import SGD
from keras import backend as K
K.set_image_data_format('channels_first')
from skimage.transform import rescale

from matplotlib.pyplot import figure, show
from sklearn.model_selection import train_test_split
import pandas as pd
import os
import numpy as np
from sklearn import metrics
from scipy.stats import zscore
import tensorflow as tf
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint
# Out:
# Using TensorFlow backend.

# %%
def preprocess_img(img):

    #img = rgb2gray(img)
    
    # thresholding and sobel filter
    #t = skimage.filters.threshold_otsu(img)
    #img = img > t

    #img = sobel_h(img)
    
    # top half crop
    #img = img[240:480,0:640]

    # downsample by 100
    img = rescale(img, scale=(0.1))
    
    # roll color to axis 0
    img = np.rollaxis(img, -1)

    return img

# %%
from skimage import io
import os
import glob


def get_class(img_path):
    return int(img_path.split('\\')[-2])

root_dir = 'dataset_train_riib/riib/train/'
imgs = []
labels = []

all_img_paths = glob.glob(os.path.join(root_dir, '*/*.pgm'))
np.random.shuffle(all_img_paths)
for img_path in all_img_paths:
    img = preprocess_img(io.imread(img_path))
    label = get_class(img_path)
    imgs.append(img)
    labels.append(label)

X = np.array(imgs, dtype='float32')
# Make one hot targets
Y = np.eye(NUM_CLASSES, dtype='uint8')[labels]
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "D:\Users\chano\Anaconda2\envs\tf-gpu\lib\site-packages\IPython\core\interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\chano\AppData\Local\Temp\ipykernel_2928\163317988.py", line 17, in <module>
#     label = get_class(img_path)
#   File "C:\Users\chano\AppData\Local\Temp\ipykernel_2928\163317988.py", line 7, in get_class
#     return int(img_path.split('\\')[-2])
# ValueError: invalid literal for int() with base 10: '2015-10-05-14-40-46_bag'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
# ...

# %%
all_img_paths = glob.glob(os.path.join(root_dir, '*/*.pgm'))
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session 218

# %%
all_img_paths
# Out:
# ['dataset_train_riib/riib/train\\2015-05-29-15-29-39_arastradero_traffic_light_loop_bag\\10648.pgm',
#  'dataset_train_riib/riib/train\\2015-05-29-15-29-39_arastradero_traffic_light_loop_bag\\10718.pgm',
#  'dataset_train_riib/riib/train\\2015-05-29-15-29-39_arastradero_traffic_light_loop_bag\\10786.pgm',
#  'dataset_train_riib/riib/train\\2015-05-29-15-29-39_arastradero_traffic_light_loop_bag\\10856.pgm',
#  'dataset_train_riib/riib/train\\2015-05-29-15-29-39_arastradero_traffic_light_loop_bag\\10926.pgm',
#  'dataset_train_riib/riib/train\\2015-05-29-15-29-39_arastradero_traffic_light_loop_bag\\10996.pgm',
#  'dataset_train_riib/riib/train\\2015-05-29-15-29-39_arastradero_traffic_light_loop_bag\\11064.pgm',
#  'dataset_train_riib/riib/train\\2015-05-29-15-29-39_arastradero_traffic_light_loop_bag\\11134.pgm',
#  'dataset_train_riib/riib/train\\2015-05-29-15-29-39_arastradero_traffic_light_loop_bag\\11204.pgm',
# ...

# %%
all_img_paths(1)
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "D:\Users\chano\Anaconda2\envs\tf-gpu\lib\site-packages\IPython\core\interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\chano\AppData\Local\Temp\ipykernel_2928\28990926.py", line 1, in <module>
#     all_img_paths(1)
# TypeError: 'list' object is not callable
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "D:\Users\chano\Anaconda2\envs\tf-gpu\lib\site-packages\IPython\core\interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# ...

# %%
all_img_paths[1]
# Out:
# 'dataset_train_riib/riib/train\\2015-05-29-15-29-39_arastradero_traffic_light_loop_bag\\10718.pgm'
# ERROR! Session/line number was not unique in database. History logging moved to new session 219

# %%
a = all_img_paths[1]

# %%
a
# Out:
# 'dataset_train_riib/riib/train\\2015-05-29-15-29-39_arastradero_traffic_light_loop_bag\\10718.pgm'

# %%
a.split('\\')[-2]
# Out:
# '2015-05-29-15-29-39_arastradero_traffic_light_loop_bag'

# %%
a = all_img_paths[600]

# %%
a
# Out:
# 'dataset_train_riib/riib/train\\2015-10-05-10-55-33_bag\\49276.pgm'

# %%
a.split('\\')[-2]
# Out:
# '2015-10-05-10-55-33_bag'

# %%
a.split('\\')[-1]
# Out:
# '49276.pgm'

# %%
import yaml
import pandas as pd
with open('train.yaml', 'r') as f:
    df = pd.io.json.json_normalize(yaml.load(f, Loader=yaml.FullLoader),'boxes', 'path' )
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "D:\Users\chano\Anaconda2\envs\tf-gpu\lib\site-packages\IPython\core\interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\chano\AppData\Local\Temp\ipykernel_2928\3031812764.py", line 2, in <module>
#     df = pd.io.json.json_normalize(yaml.load(f, Loader=yaml.FullLoader),'boxes', 'path' )
# NameError: name 'yaml' is not defined
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
# ...

# %%
import yaml
import pandas as pd
with open('train.yaml', 'r') as f:
    df = pd.io.json.json_normalize(yaml.load(f, Loader=yaml.FullLoader),'boxes', 'path' )
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session 220

# %%
df
# Out:
#          label  occluded       x_max       x_min       y_max       y_min  \
# 0       Yellow      True  615.750000  610.625000  358.625000  351.500000
# 1       Yellow     False  638.125000  633.875000  351.000000  342.250000
# 2       Yellow     False  655.000000  649.500000  360.750000  350.375000
# 3      RedLeft      True  615.500000  612.000000  360.375000  354.750000
# 4          Red     False  636.625000  632.250000  355.375000  346.375000
# ...        ...       ...         ...         ...         ...         ...
# 10751    Green     False  590.047547  573.580846  219.137754  175.765818
# 10752    Green     False  544.689352  508.938214   71.680937    1.331923
# 10753    Green     False  892.943457  861.151823  224.574408  154.392877
# 10754    Green     False  582.341789  573.372644  276.627118  256.311463
# 10755    Green     False  517.626782  510.027687  273.164089  256.427986
#
#                                                     path
# ...

# %%
df('path')[1]
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "D:\Users\chano\Anaconda2\envs\tf-gpu\lib\site-packages\IPython\core\interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\chano\AppData\Local\Temp\ipykernel_2928\567481175.py", line 1, in <module>
#     df('path')[1]
# TypeError: 'DataFrame' object is not callable
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "D:\Users\chano\Anaconda2\envs\tf-gpu\lib\site-packages\IPython\core\interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# ...

# %%
df['path']
# Out:
# 0        ./rgb/train/2017-02-03-11-44-56_los_altos_moun...
# 1        ./rgb/train/2017-02-03-11-44-56_los_altos_moun...
# 2        ./rgb/train/2017-02-03-11-44-56_los_altos_moun...
# 3        ./rgb/train/2017-02-03-11-44-56_los_altos_moun...
# 4        ./rgb/train/2017-02-03-11-44-56_los_altos_moun...
#                                ...
# 10751       ./rgb/train/2015-10-05-16-02-30_bag/720238.png
# 10752       ./rgb/train/2015-10-05-16-02-30_bag/720308.png
# 10753       ./rgb/train/2015-10-05-16-02-30_bag/720308.png
# 10754       ./rgb/train/2015-10-05-16-02-30_bag/720654.png
# 10755       ./rgb/train/2015-10-05-16-02-30_bag/720654.png
# Name: path, Length: 10756, dtype: object
# ERROR! Session/line number was not unique in database. History logging moved to new session 221

# %%
df['path'](0)
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "D:\Users\chano\Anaconda2\envs\tf-gpu\lib\site-packages\IPython\core\interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\chano\AppData\Local\Temp\ipykernel_2928\3211880331.py", line 1, in <module>
#     df['path'](0)
# TypeError: 'Series' object is not callable
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "D:\Users\chano\Anaconda2\envs\tf-gpu\lib\site-packages\IPython\core\interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# ...

# %%
df['path'][0]
# Out:
# './rgb/train/2017-02-03-11-44-56_los_altos_mountain_view_traffic_lights_bag/207386.png'
# ERROR! Session/line number was not unique in database. History logging moved to new session 222

# %%
df['path'][1]
# Out:
# './rgb/train/2017-02-03-11-44-56_los_altos_mountain_view_traffic_lights_bag/207386.png'

# %%
if  (df['path'][0]) == (df['path'][1])
# Out:
#   File "C:\Users\chano\AppData\Local\Temp\ipykernel_2928\4157391557.py", line 1
#     if  (df['path'][0]) == (df['path'][1])
#                                           ^
# SyntaxError: invalid syntax

# %%
if  (df['path'][0]) == (df['path'][1]):
    true
# Out:
#   File "C:\Users\chano\AppData\Local\Temp\ipykernel_2928\3268524742.py", line 1
#     if  (df['path'][0]) == (df['path'][1])
#                                           ^
# SyntaxError: invalid syntax

# %%
if  (df['path'][0]) == (df['path'][1]):
# Out:
#   File "C:\Users\chano\AppData\Local\Temp\ipykernel_2928\3794821434.py", line 1
#     if  (df['path'][0]) == (df['path'][1]):
#                                            ^
# SyntaxError: unexpected EOF while parsing

# %%
if  (df['path'][0]) == (df['path'][1]);
# Out:
#   File "C:\Users\chano\AppData\Local\Temp\ipykernel_2928\4095142159.py", line 1
#     if  (df['path'][0]) == (df['path'][1]);
#                                           ^
# SyntaxError: invalid syntax

# %%
if  (df['path'][0]) == (df['path'][1]) : print "true"
# Out:
#   File "C:\Users\chano\AppData\Local\Temp\ipykernel_2928\1538844440.py", line 1
#     if  (df['path'][0]) == (df['path'][1]) : print "true"
#                                                         ^
# SyntaxError: invalid syntax

# %%
if ((df['path'][0]) == (df['path'][1])) : print "true"
# Out:
#   File "C:\Users\chano\AppData\Local\Temp\ipykernel_2928\3014991228.py", line 1
#     if ((df['path'][0]) == (df['path'][1])) : print "true"
#                                                          ^
# SyntaxError: invalid syntax

# %%
if ((df['path'][0]) == (df['path'][1])) : print 'true'
# Out:
#   File "C:\Users\chano\AppData\Local\Temp\ipykernel_2928\3754290009.py", line 1
#     if ((df['path'][0]) == (df['path'][1])) : print 'true'
#                                                          ^
# SyntaxError: invalid syntax

# %%
if ((df['path'][0]) == (df['path'][1])) 
    print "true"
# Out:
#   File "C:\Users\chano\AppData\Local\Temp\ipykernel_2928\1671007537.py", line 1
#     if ((df['path'][0]) == (df['path'][1]))
#                                             ^
# SyntaxError: invalid syntax

# %%
if ((df['path'][0]) == (df['path'][1])):
    print "true"
# Out:
#   File "C:\Users\chano\AppData\Local\Temp\ipykernel_2928\2388119236.py", line 2
#     print "true"
#                ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print("true")?

# %%
if ((df['path'][0]) == (df['path'][1])) 
    print ()"true")
# Out:
#   File "C:\Users\chano\AppData\Local\Temp\ipykernel_2928\933602912.py", line 1
#     if ((df['path'][0]) == (df['path'][1]))
#                                             ^
# SyntaxError: invalid syntax

# %%
if ((df['path'][0]) == (df['path'][1])) 
    print ("true")
# Out:
#   File "C:\Users\chano\AppData\Local\Temp\ipykernel_2928\3577418881.py", line 1
#     if ((df['path'][0]) == (df['path'][1]))
#                                             ^
# SyntaxError: invalid syntax

# %%
if ((df['path'][0]) == (df['path'][1])): 
    print ("true")
# Out:
# true

# %%
if ((df['path'][0]) == (df['path'][10000])):
    print ("true")
    else 
        print("not true")
# Out:
#   File "C:\Users\chano\AppData\Local\Temp\ipykernel_2928\459827764.py", line 3
#     else
#        ^
# SyntaxError: invalid syntax

# %%
if ((df['path'][0]) == (df['path'][10000])):
    print ("true")
    else 
    print("not true")
# Out:
#   File "C:\Users\chano\AppData\Local\Temp\ipykernel_2928\2081069239.py", line 3
#     else
#        ^
# SyntaxError: invalid syntax

# %%
if ((df['path'][0]) == (df['path'][10000])):
    print ("true")
    else :
    print("not true")
# Out:
#   File "C:\Users\chano\AppData\Local\Temp\ipykernel_2928\1140816640.py", line 3
#     else :
#        ^
# SyntaxError: invalid syntax

# %%
if ((df['path'][0]) == (df['path'][10000])):
    print ("true")
else :
    print("not true")
# Out:
# not true

# %%
df.shape
# Out:
# (10756, 7)

# %%
a = df.shape

# %%
a
# Out:
# (10756, 7)

# %%
a = df.shape(1)
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "D:\Users\chano\Anaconda2\envs\tf-gpu\lib\site-packages\IPython\core\interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\chano\AppData\Local\Temp\ipykernel_2928\2346169144.py", line 1, in <module>
#     a = df.shape(1)
# TypeError: 'tuple' object is not callable
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "D:\Users\chano\Anaconda2\envs\tf-gpu\lib\site-packages\IPython\core\interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# ...

# %%
a = df.shape[1]
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session 223

# %%
a
# Out:
# 7

# %%
a = df.shape[0]

# %%
a
# Out:
# 10756

# %%
os.path.join(root_dir, '*/*.pgm')
# Out:
# 'dataset_train_riib/riib/train/*/*.pgm'

# %%
df['path'][0])
# Out:
#   File "C:\Users\chano\AppData\Local\Temp\ipykernel_2928\320961495.py", line 1
#     df['path'][0])
#                  ^
# SyntaxError: invalid syntax

# %%
df['path'][0]
# Out:
# './rgb/train/2017-02-03-11-44-56_los_altos_mountain_view_traffic_lights_bag/207386.png'

# %%
if ((df['path'][0]) == (df['path'][10000])):
    print ("true")
else :
    print("not true")
# Out:
# not true

# %%
if ((df['path'][0]) == (df['path'][1])):
    print ("true")
else :
    print("not true")
# Out:
# true

# %%
if ((df['path'][0]) == (df['path'][1])):
    print ("true")
else :
    print("not true")
# Out:
# true

# %%
if ((df['path'][0]) == (df['path'][1])):
    if ((df['xmax'][0]-df['xmin'][0])*(df['ymax'][0]-df['ymin'][0])) >=  ((df['xmax'][1]-df['xmin'][1])*(df['ymax'][1]-df['ymin'][1])):
        print ("true")
    else :
        print("not true")
# Out:
#   File "C:\Users\chano\AppData\Local\Temp\ipykernel_2928\848299557.py", line 2
#     if ((df['xmax'][0]-df['xmin'][0])*(df['ymax'][0]-df['ymin'][0])) >=  ((df['xmax'][1]-df['xmin'][1])*(df['ymax'][1]-df['ymin'][1]))
#                                                                                                                                       ^
# SyntaxError: invalid syntax

# %%
if ((df['path'][0]) == (df['path'][1])):
    if ((df['xmax'][0]-df['xmin'][0])*(df['ymax'][0]-df['ymin'][0])) >=  ((df['xmax'][1]-df['xmin'][1])*(df['ymax'][1]-df['ymin'][1])):
        print ("true")
    else :
        print("not true")
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "D:\Users\chano\Anaconda2\envs\tf-gpu\lib\site-packages\pandas\core\indexes\base.py", line 2890, in get_loc
#     return self._engine.get_loc(key)
#   File "pandas\_libs\index.pyx", line 107, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\index.pyx", line 131, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\hashtable_class_helper.pxi", line 1607, in pandas._libs.hashtable.PyObjectHashTable.get_item
#   File "pandas\_libs\hashtable_class_helper.pxi", line 1614, in pandas._libs.hashtable.PyObjectHashTable.get_item
# KeyError: 'xmax'
#
# ...

# %%
if ((df['path'][0]) == (df['path'][1])):
    if ((df['x_max'][0]-df['x_min'][0])*(df['y_max'][0]-df['y_min'][0])) >=  ((df['x_max'][1]-df['x_min'][1])*(df['y_max'][1]-df['y_min'][1])):
        print ("true")
    else :
        print("not true")
# Out:
# not true
# ERROR! Session/line number was not unique in database. History logging moved to new session 224

# %%
if ((df['path'][0]) == (df['path'][1])):
    if ((df['x_max'][0]-df['x_min'][0])*(df['y_max'][0]-df['y_min'][0])) >=  ((df['x_max'][1]-df['x_min'][1])*(df['y_max'][1]-df['y_min'][1])):
        df.drop(0,1, inplace = True)
    else :
        df.drop(0,0, inplace = True)

# %%
df.loc[0:4]
# Out:
#      label  occluded    x_max    x_min    y_max    y_min  \
# 1   Yellow     False  638.125  633.875  351.000  342.250
# 2   Yellow     False  655.000  649.500  360.750  350.375
# 3  RedLeft      True  615.500  612.000  360.375  354.750
# 4      Red     False  636.625  632.250  355.375  346.375
#
#                                                 path
# 1  ./rgb/train/2017-02-03-11-44-56_los_altos_moun...
# 2  ./rgb/train/2017-02-03-11-44-56_los_altos_moun...
# 3  ./rgb/train/2017-02-03-11-44-56_los_altos_moun...
# 4  ./rgb/train/2017-02-03-11-44-56_los_altos_moun...

# %%
i = 0
def fix_df(df, i):
    if ((df['path'][i]) == (df['path'][i+1])):
        if ((df['x_max'][i]-df['x_min'][i])*(df['y_max'][i]-df['y_min'][i])) >=  ((df['x_max'][i+1]-df['x_min'][i+1])*(df['y_max'][i+1]-df['y_min'][i+1])):
            df.drop(0,i, inplace = True)
        else :
            df.drop(0,i+1, inplace = True)
    else: 
        i = i+1
        df = fix_df(df,i)
    return df

# %%
df
# Out:
#          label  occluded       x_max       x_min       y_max       y_min  \
# 1       Yellow     False  638.125000  633.875000  351.000000  342.250000
# 2       Yellow     False  655.000000  649.500000  360.750000  350.375000
# 3      RedLeft      True  615.500000  612.000000  360.375000  354.750000
# 4          Red     False  636.625000  632.250000  355.375000  346.375000
# 5          Red     False  653.875000  649.250000  364.875000  353.500000
# ...        ...       ...         ...         ...         ...         ...
# 10751    Green     False  590.047547  573.580846  219.137754  175.765818
# 10752    Green     False  544.689352  508.938214   71.680937    1.331923
# 10753    Green     False  892.943457  861.151823  224.574408  154.392877
# 10754    Green     False  582.341789  573.372644  276.627118  256.311463
# 10755    Green     False  517.626782  510.027687  273.164089  256.427986
#
#                                                     path
# ...

# %%
i
# Out:
# 0

# %%
i = 0

def fix_df(df, i):
    if ((df['path'][i]) == (df['path'][i+1])):
        if ((df['x_max'][i]-df['x_min'][i])*(df['y_max'][i]-df['y_min'][i])) >=  ((df['x_max'][i+1]-df['x_min'][i+1])*(df['y_max'][i+1]-df['y_min'][i+1])):
            df.drop(0,i, inplace = True)
        else :
            df.drop(0,i+1, inplace = True)
    else: 
        i = i+1
        df = fix_df(df,i)
    return df

df = fix_df(df,i)
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "D:\Users\chano\Anaconda2\envs\tf-gpu\lib\site-packages\IPython\core\interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\chano\AppData\Local\Temp\ipykernel_2928\3463458393.py", line 14, in <module>
#     df = fix_df(df,i)
#   File "C:\Users\chano\AppData\Local\Temp\ipykernel_2928\3463458393.py", line 4, in fix_df
#     if ((df['path'][i]) == (df['path'][i+1])):
#   File "D:\Users\chano\Anaconda2\envs\tf-gpu\lib\site-packages\pandas\core\series.py", line 1064, in __getitem__
#     result = self.index.get_value(self, key)
# ...

# %%
df
# Out:
#          label  occluded       x_max       x_min       y_max       y_min  \
# 1       Yellow     False  638.125000  633.875000  351.000000  342.250000
# 2       Yellow     False  655.000000  649.500000  360.750000  350.375000
# 3      RedLeft      True  615.500000  612.000000  360.375000  354.750000
# 4          Red     False  636.625000  632.250000  355.375000  346.375000
# 5          Red     False  653.875000  649.250000  364.875000  353.500000
# ...        ...       ...         ...         ...         ...         ...
# 10751    Green     False  590.047547  573.580846  219.137754  175.765818
# 10752    Green     False  544.689352  508.938214   71.680937    1.331923
# 10753    Green     False  892.943457  861.151823  224.574408  154.392877
# 10754    Green     False  582.341789  573.372644  276.627118  256.311463
# 10755    Green     False  517.626782  510.027687  273.164089  256.427986
#
#                                                     path
# ...

# %%
i
# Out:
# 0

# %%
i = 0

def fix_df(df, i):
    if ((df['path'][i]) == (df['path'][i+1])):
        if ((df['x_max'][i]-df['x_min'][i])*(df['y_max'][i]-df['y_min'][i])) >=  ((df['x_max'][i+1]-df['x_min'][i+1])*(df['y_max'][i+1]-df['y_min'][i+1])):
            df.drop(0,i, inplace = True)
        else :
            df.drop(0,i+1, inplace = True)
            df = fix_df(df,i)            
    else: 
        i = i+1
        df = fix_df(df,i)
    return df

df = fix_df(df,i)
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "D:\Users\chano\Anaconda2\envs\tf-gpu\lib\site-packages\IPython\core\interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\chano\AppData\Local\Temp\ipykernel_2928\2578624581.py", line 15, in <module>
#     df = fix_df(df,i)
#   File "C:\Users\chano\AppData\Local\Temp\ipykernel_2928\2578624581.py", line 4, in fix_df
#     if ((df['path'][i]) == (df['path'][i+1])):
#   File "D:\Users\chano\Anaconda2\envs\tf-gpu\lib\site-packages\pandas\core\series.py", line 1064, in __getitem__
#     result = self.index.get_value(self, key)
# ...

# %%
 df
# Out:
#          label  occluded       x_max       x_min       y_max       y_min  \
# 1       Yellow     False  638.125000  633.875000  351.000000  342.250000
# 2       Yellow     False  655.000000  649.500000  360.750000  350.375000
# 3      RedLeft      True  615.500000  612.000000  360.375000  354.750000
# 4          Red     False  636.625000  632.250000  355.375000  346.375000
# 5          Red     False  653.875000  649.250000  364.875000  353.500000
# ...        ...       ...         ...         ...         ...         ...
# 10751    Green     False  590.047547  573.580846  219.137754  175.765818
# 10752    Green     False  544.689352  508.938214   71.680937    1.331923
# 10753    Green     False  892.943457  861.151823  224.574408  154.392877
# 10754    Green     False  582.341789  573.372644  276.627118  256.311463
# 10755    Green     False  517.626782  510.027687  273.164089  256.427986
#
#                                                     path
# ...

# %%
i = 0

def fix_df(df, i):
    if ((df['path'][i]) == (df['path'][i+1])):
        if ((df['x_max'][i]-df['x_min'][i])*(df['y_max'][i]-df['y_min'][i])) >=  ((df['x_max'][i+1]-df['x_min'][i+1])*(df['y_max'][i+1]-df['y_min'][i+1])):
            df.drop(0,i, inplace = True)
        else :
            df.drop(0,i+1, inplace = True)
            df = fix_df(df,i)            
    else: 
        i = i+1
        df = fix_df(df,i)
    return df

df = fix_df(df,i)
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "D:\Users\chano\Anaconda2\envs\tf-gpu\lib\site-packages\IPython\core\interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\chano\AppData\Local\Temp\ipykernel_2928\2578624581.py", line 15, in <module>
#     df = fix_df(df,i)
#   File "C:\Users\chano\AppData\Local\Temp\ipykernel_2928\2578624581.py", line 4, in fix_df
#     if ((df['path'][i]) == (df['path'][i+1])):
#   File "D:\Users\chano\Anaconda2\envs\tf-gpu\lib\site-packages\pandas\core\series.py", line 1064, in __getitem__
#     result = self.index.get_value(self, key)
# ...

# %%
def fix_df(df, j):
    if ((df['path'][j]) == (df['path'][j+1])):
        if ((df['x_max'][j]-df['x_min'][j])*(df['y_max'][j]-df['y_min'][j])) >=  ((df['x_max'][j+1]-df['x_min'][j+1])*(df['y_max'][j+1]-df['y_min'][j+1])):
            df.drop(0,j, inplace = True)
        else :
            df.drop(0,j+1, inplace = True)
            df = fix_df(df,j)            
    else: 
        j = j+1
        df = fix_df(df,j)
    return df
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session 227

# %%
i = 0
df = fix_df(df,i)
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "D:\Users\chano\Anaconda2\envs\tf-gpu\lib\site-packages\IPython\core\interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\chano\AppData\Local\Temp\ipykernel_2928\72966426.py", line 2, in <module>
#     df = fix_df(df,i)
#   File "C:\Users\chano\AppData\Local\Temp\ipykernel_2928\803415170.py", line 2, in fix_df
#     if ((df['path'][i]) == (df['path'][i+1])):
#   File "D:\Users\chano\Anaconda2\envs\tf-gpu\lib\site-packages\pandas\core\series.py", line 1064, in __getitem__
#     result = self.index.get_value(self, key)
# ...

# %%
def fix_df(df, j):
    if ((df['path'][j]) == (df['path'][j+1])):
        if ((df['x_max'][j]-df['x_min'][j])*(df['y_max'][j]-df['y_min'][j])) >=  ((df['x_max'][j+1]-df['x_min'][j+1])*(df['y_max'][j+1]-df['y_min'][j+1])):
            df.drop(0,j, inplace = True)
        else :
            df.drop(0,j+1, inplace = True)
            df = fix_df(df,j)            
    else: 
        j = j+1
        df = fix_df(df,j)
    return df
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session 228

# %%
i = 0
df = fix_df(df,i)
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "D:\Users\chano\Anaconda2\envs\tf-gpu\lib\site-packages\IPython\core\interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\chano\AppData\Local\Temp\ipykernel_2928\72966426.py", line 2, in <module>
#     df = fix_df(df,i)
#   File "C:\Users\chano\AppData\Local\Temp\ipykernel_2928\2086672213.py", line 2, in fix_df
#     if ((df['path'][j]) == (df['path'][j+1])):
#   File "D:\Users\chano\Anaconda2\envs\tf-gpu\lib\site-packages\pandas\core\series.py", line 1064, in __getitem__
#     result = self.index.get_value(self, key)
# ...

# %%
df
# Out:
# ERROR! Session/line number was not unique in
#          label  occluded       x_max       x_min       y_max       y_min  \
# 1       Yellow     False  638.125000  633.875000  351.000000  342.250000
# 2       Yellow     False  655.000000  649.500000  360.750000  350.375000
# 3      RedLeft      True  615.500000  612.000000  360.375000  354.750000
# 4          Red     False  636.625000  632.250000  355.375000  346.375000
# 5          Red     False  653.875000  649.250000  364.875000  353.500000
# ...        ...       ...         ...         ...         ...         ...
# 10751    Green     False  590.047547  573.580846  219.137754  175.765818
# 10752    Green     False  544.689352  508.938214   71.680937    1.331923
# 10753    Green     False  892.943457  861.151823  224.574408  154.392877
# 10754    Green     False  582.341789  573.372644  276.627118  256.311463
# 10755    Green     False  517.626782  510.027687  273.164089  256.427986
#
# ...

# %%
def fix_df(df, j):
    if ((df['path'][j]) == (df['path'][j+1])):
        if ((df['x_max'][j]-df['x_min'][j])*(df['y_max'][j]-df['y_min'][j])) >=  ((df['x_max'][j+1]-df['x_min'][j+1])*(df['y_max'][j+1]-df['y_min'][j+1])):
            df.drop(0,j+1, inplace = True)
        else :
            df.drop(0,j, inplace = True)
            df = fix_df(df,j)            
    else: 
        j = j+1
        df = fix_df(df,j)
    return df

# %%
i = 0
df = fix_df(df,i)
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "D:\Users\chano\Anaconda2\envs\tf-gpu\lib\site-packages\IPython\core\interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\chano\AppData\Local\Temp\ipykernel_2928\72966426.py", line 2, in <module>
#     df = fix_df(df,i)
#   File "C:\Users\chano\AppData\Local\Temp\ipykernel_2928\3274090626.py", line 2, in fix_df
#     if ((df['path'][j]) == (df['path'][j+1])):
#   File "D:\Users\chano\Anaconda2\envs\tf-gpu\lib\site-packages\pandas\core\series.py", line 1064, in __getitem__
#     result = self.index.get_value(self, key)
#   File "D:\Users\chano\Anaconda2\envs\tf-gpu\lib\site-packages\pandas\core\indexes\base.py", line 4723, in get_value
# ...

# %%
i = 0
a = df.shape(0)
while i< 
    if ((df['path'][j]) == (df['path'][j+1])):
        if ((df['x_max'][j]-df['x_min'][j])*(df['y_max'][j]-df['y_min'][j])) >=  ((df['x_max'][j+1]-df['x_min'][j+1])*(df['y_max'][j+1]-df['y_min'][j+1])):
            df.drop(0,j+1, inplace = True)
        else :
            df.drop(0,j, inplace = True)
            df = fix_df(df,j)            
    else: 
        j = j+1
        df = fix_df(df,j)
    return df

# %%
a = df.shape(0)
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "D:\Users\chano\Anaconda2\envs\tf-gpu\lib\site-packages\IPython\core\interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\chano\AppData\Local\Temp\ipykernel_2928\245408381.py", line 1, in <module>
#     a = df.shape(0)
# TypeError: 'tuple' object is not callable
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "D:\Users\chano\Anaconda2\envs\tf-gpu\lib\site-packages\IPython\core\interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# ...

# %%
a = df.shape[0]
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session 231

# %%
a
# Out:
# 10755

# %%
i = 0
a = df.shape[0]
while i < a:
    if ((df['path'][i]) == (df['path'][i+1])):
        if ((df['x_max'][i]-df['x_min'][i])*(df['y_max'][i]-df['y_min'][i])) >=  ((df['x_max'][i+1]-df['x_min'][i+1])*(df['y_max'][i+1]-df['y_min'][i+1])):
            df.drop(0,i+1, inplace = True)
        else :
            df.drop(0,i, inplace = True)
            continue          
    else: 
        i = i+1
        continue
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "D:\Users\chano\Anaconda2\envs\tf-gpu\lib\site-packages\IPython\core\interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\chano\AppData\Local\Temp\ipykernel_2928\95578162.py", line 4, in <module>
#     if ((df['path'][i]) == (df['path'][i+1])):
#   File "D:\Users\chano\Anaconda2\envs\tf-gpu\lib\site-packages\pandas\core\series.py", line 1064, in __getitem__
#     result = self.index.get_value(self, key)
#   File "D:\Users\chano\Anaconda2\envs\tf-gpu\lib\site-packages\pandas\core\indexes\base.py", line 4723, in get_value
#     return self._engine.get_value(s, k, tz=getattr(series.dtype, "tz", None))
# ...

# %%
df
# Out:
#          label  occluded       x_max       x_min       y_max       y_min  \
# 1       Yellow     False  638.125000  633.875000  351.000000  342.250000
# 2       Yellow     False  655.000000  649.500000  360.750000  350.375000
# 3      RedLeft      True  615.500000  612.000000  360.375000  354.750000
# 4          Red     False  636.625000  632.250000  355.375000  346.375000
# 5          Red     False  653.875000  649.250000  364.875000  353.500000
# ...        ...       ...         ...         ...         ...         ...
# 10751    Green     False  590.047547  573.580846  219.137754  175.765818
# 10752    Green     False  544.689352  508.938214   71.680937    1.331923
# 10753    Green     False  892.943457  861.151823  224.574408  154.392877
# 10754    Green     False  582.341789  573.372644  276.627118  256.311463
# 10755    Green     False  517.626782  510.027687  273.164089  256.427986
#
#                                                     path
# ...

# %%
a
# Out:
# 10755

# %%
i = 0
a = df.shape[0]
while i < a:
    if ((df['path'][i]) == (df['path'][i+1])):
        if ((df['x_max'][i]-df['x_min'][i])*(df['y_max'][i]-df['y_min'][i])) >=  ((df['x_max'][i+1]-df['x_min'][i+1])*(df['y_max'][i+1]-df['y_min'][i+1])):
            df.drop(0,i+1, inplace = True)
            a = a - 1
            continue
        else :
            df.drop(0,i, inplace = True)
            a = a - 1
            continue          
    else: 
        i = i+1
        continue
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "D:\Users\chano\Anaconda2\envs\tf-gpu\lib\site-packages\IPython\core\interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\chano\AppData\Local\Temp\ipykernel_2928\95578162.py", line 4, in <module>
#     if ((df['path'][i]) == (df['path'][i+1])):
#   File "D:\Users\chano\Anaconda2\envs\tf-gpu\lib\site-packages\pandas\core\series.py", line 1064, in __getitem__
#     result = self.index.get_value(self, key)
#   File "D:\Users\chano\Anaconda2\envs\tf-gpu\lib\site-packages\pandas\core\indexes\base.py", line 4723, in get_value
#     return self._engine.get_value(s, k, tz=getattr(series.dtype, "tz", None))
# ...

# %%
i = 0
a = df.shape[0]
while i < a:
    if ((df['path'][i]) == (df['path'][i+1])):
        if ((df['x_max'][i]-df['x_min'][i])*(df['y_max'][i]-df['y_min'][i])) >=  ((df['x_max'][i+1]-df['x_min'][i+1])*(df['y_max'][i+1]-df['y_min'][i+1])):
            df.drop(0,i+1, inplace = True)
            a = a - 1
            continue
        else :
            df.drop(0,i, inplace = True)
            a = a - 1
            continue          
    else: 
        i = i+1
        continue
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# ERROR! Session/line number was not unique in database. History logging moved to new session 233
# Traceback (most recent call last):
#   File "D:\Users\chano\Anaconda2\envs\tf-gpu\lib\site-packages\IPython\core\interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\chano\AppData\Local\Temp\ipykernel_2928\630448509.py", line 4, in <module>
#     if ((df['path'][i]) == (df['path'][i+1])):
#   File "D:\Users\chano\Anaconda2\envs\tf-gpu\lib\site-packages\pandas\core\series.py", line 1064, in __getitem__
#     result = self.index.get_value(self, key)
#   File "D:\Users\chano\Anaconda2\envs\tf-gpu\lib\site-packages\pandas\core\indexes\base.py", line 4723, in get_value
# ...

# %%
i
# Out:
# 0
# ERROR! Session/line number was not unique in database. History logging moved to new session 234

# %%
df['path'][i]
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "D:\Users\chano\Anaconda2\envs\tf-gpu\lib\site-packages\IPython\core\interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\chano\AppData\Local\Temp\ipykernel_2928\2088131877.py", line 1, in <module>
#     df['path'][i]
#   File "D:\Users\chano\Anaconda2\envs\tf-gpu\lib\site-packages\pandas\core\series.py", line 1064, in __getitem__
#     result = self.index.get_value(self, key)
#   File "D:\Users\chano\Anaconda2\envs\tf-gpu\lib\site-packages\pandas\core\indexes\base.py", line 4723, in get_value
#     return self._engine.get_value(s, k, tz=getattr(series.dtype, "tz", None))
#   File "pandas\_libs\index.pyx", line 80, in pandas._libs.index.IndexEngine.get_value
# ...

# %%
df['path'][1]
# Out:
# './rgb/train/2017-02-03-11-44-56_los_altos_mountain_view_traffic_lights_bag/207386.png'
# ERROR! Session/line number was not unique in database. History logging moved to new session 235

# %%
df['path'][i]
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "D:\Users\chano\Anaconda2\envs\tf-gpu\lib\site-packages\IPython\core\interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\chano\AppData\Local\Temp\ipykernel_2928\2088131877.py", line 1, in <module>
#     df['path'][i]
#   File "D:\Users\chano\Anaconda2\envs\tf-gpu\lib\site-packages\pandas\core\series.py", line 1064, in __getitem__
#     result = self.index.get_value(self, key)
#   File "D:\Users\chano\Anaconda2\envs\tf-gpu\lib\site-packages\pandas\core\indexes\base.py", line 4723, in get_value
#     return self._engine.get_value(s, k, tz=getattr(series.dtype, "tz", None))
#   File "pandas\_libs\index.pyx", line 80, in pandas._libs.index.IndexEngine.get_value
# ...

# %%
i
# Out:
# 0
# ERROR! Session/line number was not unique in database. History logging moved to new session 236

# %%
i = 8

# %%
i
# Out:
# 8

# %%
df['path'][8]
# Out:
# './rgb/train/2017-02-03-11-44-56_los_altos_mountain_view_traffic_lights_bag/207458.png'

# %%
df['path'][i]
# Out:
# './rgb/train/2017-02-03-11-44-56_los_altos_mountain_view_traffic_lights_bag/207458.png'

# %%
i = 0

# %%
df['path'][i]
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "D:\Users\chano\Anaconda2\envs\tf-gpu\lib\site-packages\IPython\core\interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\chano\AppData\Local\Temp\ipykernel_2928\2088131877.py", line 1, in <module>
#     df['path'][i]
#   File "D:\Users\chano\Anaconda2\envs\tf-gpu\lib\site-packages\pandas\core\series.py", line 1064, in __getitem__
#     result = self.index.get_value(self, key)
#   File "D:\Users\chano\Anaconda2\envs\tf-gpu\lib\site-packages\pandas\core\indexes\base.py", line 4723, in get_value
#     return self._engine.get_value(s, k, tz=getattr(series.dtype, "tz", None))
#   File "pandas\_libs\index.pyx", line 80, in pandas._libs.index.IndexEngine.get_value
# ...

# %%
df['path'][3]
# Out:
# './rgb/train/2017-02-03-11-44-56_los_altos_mountain_view_traffic_lights_bag/207390.png'
# ERROR! Session/line number was not unique in database. History logging moved to new session 237

# %%
i = 3
a = df.shape[0]-2
while i < a:
    if ((df['path'][i]) == (df['path'][i+1])):
        if ((df['x_max'][i]-df['x_min'][i])*(df['y_max'][i]-df['y_min'][i])) >=  ((df['x_max'][i+1]-df['x_min'][i+1])*(df['y_max'][i+1]-df['y_min'][i+1])):
            df.drop(0,i+1, inplace = True)
            a = a - 1
            continue
        else :
            df.drop(0,i, inplace = True)
            a = a - 1
            continue          
    else: 
        i = i+1
        continue
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "D:\Users\chano\Anaconda2\envs\tf-gpu\lib\site-packages\IPython\core\interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\chano\AppData\Local\Temp\ipykernel_2928\3726700928.py", line 10, in <module>
#     df.drop(0,i, inplace = True)
#   File "D:\Users\chano\Anaconda2\envs\tf-gpu\lib\site-packages\pandas\core\frame.py", line 4097, in drop
#     errors=errors,
#   File "D:\Users\chano\Anaconda2\envs\tf-gpu\lib\site-packages\pandas\core\generic.py", line 3902, in drop
#     axis_name = self._get_axis_name(axis)
#   File "D:\Users\chano\Anaconda2\envs\tf-gpu\lib\site-packages\pandas\core\generic.py", line 425, in _get_axis_name
# ...

# %%
i
# Out:
# 3
# ERROR! Session/line number was not unique in database. History logging moved to new session 238

# %%
df['path'][i]
# Out:
# './rgb/train/2017-02-03-11-44-56_los_altos_mountain_view_traffic_lights_bag/207390.png'

# %%
df['path'][i+1]
# Out:
# './rgb/train/2017-02-03-11-44-56_los_altos_mountain_view_traffic_lights_bag/207390.png'

# %%
def fix_df(df, j):
    if ((df['path'][j]) == (df['path'][j+1])):
        if ((df['x_max'][j]-df['x_min'][j])*(df['y_max'][j]-df['y_min'][j])) >=  ((df['x_max'][j+1]-df['x_min'][j+1])*(df['y_max'][j+1]-df['y_min'][j+1])):
            df.drop(0,j+1, inplace = True)
        else :
            df.drop(0,j, inplace = True)
            df = fix_df(df,j)            
    else: 
        j = j+1
        df = fix_df(df,j)
    return df

# %%
i = 3

# %%
df =fix_df(df,i)
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "D:\Users\chano\Anaconda2\envs\tf-gpu\lib\site-packages\IPython\core\interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\chano\AppData\Local\Temp\ipykernel_2928\3323677396.py", line 1, in <module>
#     df =fix_df(df,i)
#   File "C:\Users\chano\AppData\Local\Temp\ipykernel_2928\3274090626.py", line 6, in fix_df
#     df.drop(0,j, inplace = True)
#   File "D:\Users\chano\Anaconda2\envs\tf-gpu\lib\site-packages\pandas\core\frame.py", line 4097, in drop
#     errors=errors,
# ...

# %%
i = 3
a = df.shape[0]-2
while i < a:
    if ((df['path'][i]) == (df['path'][i+1])):
        if ((df['x_max'][i]-df['x_min'][i])*(df['y_max'][i]-df['y_min'][i])) >=  ((df['x_max'][i+1]-df['x_min'][i+1])*(df['y_max'][i+1]-df['y_min'][i+1])):
            df.drop(0,i+1, inplace = True)
            a = a - 1
            continue
        else :
            df.drop(0,i, inplace = True)
            a = a - 1
            continue          
    else: 
        i = i+1
        continue
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "D:\Users\chano\Anaconda2\envs\tf-gpu\lib\site-packages\IPython\core\interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\chano\AppData\Local\Temp\ipykernel_2928\3726700928.py", line 10, in <module>
#     df.drop(0,i, inplace = True)
#   File "D:\Users\chano\Anaconda2\envs\tf-gpu\lib\site-packages\pandas\core\frame.py", line 4097, in drop
#     errors=errors,
#   File "D:\Users\chano\Anaconda2\envs\tf-gpu\lib\site-packages\pandas\core\generic.py", line 3902, in drop
#     axis_name = self._get_axis_name(axis)
# ...

# %%
  if ((df['path'][i]) == (df['path'][i+1])):
        if ((df['x_max'][i]-df['x_min'][i])*(df['y_max'][i]-df['y_min'][i])) >=  ((df['x_max'][i+1]-df['x_min'][i+1])*(df['y_max'][i+1]-df['y_min'][i+1])):
            df.drop(0,i+1, inplace = True)
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session 240

# %%
df
# Out:
#          label  occluded       x_max       x_min       y_max       y_min  \
# 1       Yellow     False  638.125000  633.875000  351.000000  342.250000
# 2       Yellow     False  655.000000  649.500000  360.750000  350.375000
# 3      RedLeft      True  615.500000  612.000000  360.375000  354.750000
# 4          Red     False  636.625000  632.250000  355.375000  346.375000
# 5          Red     False  653.875000  649.250000  364.875000  353.500000
# ...        ...       ...         ...         ...         ...         ...
# 10751    Green     False  590.047547  573.580846  219.137754  175.765818
# 10752    Green     False  544.689352  508.938214   71.680937    1.331923
# 10753    Green     False  892.943457  861.151823  224.574408  154.392877
# 10754    Green     False  582.341789  573.372644  276.627118  256.311463
# 10755    Green     False  517.626782  510.027687  273.164089  256.427986
#
#                                                     path
# ...

# %%
df['path'][i]
# Out:
# './rgb/train/2017-02-03-11-44-56_los_altos_mountain_view_traffic_lights_bag/207390.png'

# %%
df['x_max'][i]
# Out:
# 615.5

# %%
i = 1
a = df.shape[0]-2
while i < a:
    if ((df['path'][i]) == (df['path'][i+1])):
        if ((df['x_max'][i]-df['x_min'][i])*(df['y_max'][i]-df['y_min'][i])) >=  ((df['x_max'][i+1]-df['x_min'][i+1])*(df['y_max'][i+1]-df['y_min'][i+1])):
            df.drop(0,i+1, inplace = True)
            a = a - 1
            continue
        else :
            df.drop(0,i, inplace = True)
            a = a - 1
            continue          
    else: 
        i = i+1
        continue
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "D:\Users\chano\Anaconda2\envs\tf-gpu\lib\site-packages\IPython\core\interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\chano\AppData\Local\Temp\ipykernel_2928\2418612106.py", line 10, in <module>
#     df.drop(0,i, inplace = True)
#   File "D:\Users\chano\Anaconda2\envs\tf-gpu\lib\site-packages\pandas\core\frame.py", line 4097, in drop
#     errors=errors,
#   File "D:\Users\chano\Anaconda2\envs\tf-gpu\lib\site-packages\pandas\core\generic.py", line 3915, in drop
#     obj = obj._drop_axis(labels, axis, level=level, errors=errors)
# ...

# %%
import yaml
import pandas as pd
with open('train.yaml', 'r') as f:
    df = pd.io.json.json_normalize(yaml.load(f, Loader=yaml.FullLoader),'boxes', 'path' )

# %%
df
# Out:
#          label  occluded       x_max       x_min       y_max       y_min  \
# 0       Yellow      True  615.750000  610.625000  358.625000  351.500000
# 1       Yellow     False  638.125000  633.875000  351.000000  342.250000
# 2       Yellow     False  655.000000  649.500000  360.750000  350.375000
# 3      RedLeft      True  615.500000  612.000000  360.375000  354.750000
# 4          Red     False  636.625000  632.250000  355.375000  346.375000
# ...        ...       ...         ...         ...         ...         ...
# 10751    Green     False  590.047547  573.580846  219.137754  175.765818
# 10752    Green     False  544.689352  508.938214   71.680937    1.331923
# 10753    Green     False  892.943457  861.151823  224.574408  154.392877
# 10754    Green     False  582.341789  573.372644  276.627118  256.311463
# 10755    Green     False  517.626782  510.027687  273.164089  256.427986
#
#                                                     path
# ...

# %%
df['path'][0]
# Out:
# './rgb/train/2017-02-03-11-44-56_los_altos_mountain_view_traffic_lights_bag/207386.png'

# %%
df['x_max'][0]
# Out:
# 615.75

# %%
def fix_df(df, j , k):
    if ((df['path'][j]) == (df['path'][j+k])):
        if ((df['x_max'][j]-df['x_min'][j])*(df['y_max'][j]-df['y_min'][j])) >=  ((df['x_max'][j+k]-df['x_min'][j+k])*(df['y_max'][j+k]-df['y_min'][j+k])):
            df.drop(0,j+k, inplace = True)
            k = k+1
            df = fix_df(df,j, k)            

        else :
            df.drop(0,j, inplace = True)
            j = j + 1
            k = 1
            df = fix_df(df,j, k)            
    else: 
        j = j+1
        k = 1
        df = fix_df(df,j, k)
    return df

# %%
i = 0,
m = 1
df = fix_df(df,i, m)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20684\1334435729.py in <module>
#       1 i = 0,
#       2 m = 1
# ----> 3 df = fix_df(df,i, m)
#
# ~\AppData\Local\Temp\ipykernel_20684\3600635897.py in fix_df(df, j, k)
#       1 def fix_df(df, j , k):
# ----> 2     if ((df['path'][j]) == (df['path'][j+k])):
#       3         if ((df['x_max'][j]-df['x_min'][j])*(df['y_max'][j]-df['y_min'][j])) >=  ((df['x_max'][j+1]-df['x_min'][j+1])*(df['y_max'][j+1]-df['y_min'][j+1])):
#       4             df.drop(0,j+1, inplace = True)
#       5             k = k+1
#
# D:\Users\chano\Anaconda2\envs\tf-gpu\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#    1062         key = com.apply_if_callable(key, self)
#    1063         try:
# -> 1064             result = self.index.get_value(self, key)
#    1065
# ...

# %%
df
# Out:
#          label  occluded       x_max       x_min       y_max       y_min  \
# 0       Yellow      True  615.750000  610.625000  358.625000  351.500000
# 1       Yellow     False  638.125000  633.875000  351.000000  342.250000
# 2       Yellow     False  655.000000  649.500000  360.750000  350.375000
# 3      RedLeft      True  615.500000  612.000000  360.375000  354.750000
# 4          Red     False  636.625000  632.250000  355.375000  346.375000
# ...        ...       ...         ...         ...         ...         ...
# 10751    Green     False  590.047547  573.580846  219.137754  175.765818
# 10752    Green     False  544.689352  508.938214   71.680937    1.331923
# 10753    Green     False  892.943457  861.151823  224.574408  154.392877
# 10754    Green     False  582.341789  573.372644  276.627118  256.311463
# 10755    Green     False  517.626782  510.027687  273.164089  256.427986
#
#                                                     path
# ...

# %%
 if ((df['path'][j]) == (df['path'][j+k])): print('true')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20684\2303926055.py in <module>
# ----> 1 if ((df['path'][j]) == (df['path'][j+k])): print('true')
#
# NameError: name 'j' is not defined

# %%
j = 0 
k = 1

# %%
 if ((df['path'][j]) == (df['path'][j+k])): print('true')
# Out:
# true

# %%
def fix_df(dframe, j , k):
    if ((dframe['path'][j]) == (dframe['path'][j+k])):
        if ((dframe['x_max'][j]-dframe['x_min'][j])*(dframe['y_max'][j]-dframe['y_min'][j])) >=  ((dframe['x_max'][j+k]-dframe['x_min'][j+k])*(dframe['y_max'][j+k]-dframe['y_min'][j+k])):
            dframe.drop(0,j+k, inplace = True)
            k = k+1
            dframe = fix_df(dframe,j, k)            

        else :
            dframe.drop(0,j, inplace = True)
            j = j + 1
            k = 1
            dframe = fix_df(dframe,j, k)            
    else: 
        j = j+1
        k = 1
        dframe = fix_df(dframe,j, k)
    return dframe

# %%
i = 0,
m = 1
df = fix_df(df,i, m)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20684\1334435729.py in <module>
#       1 i = 0,
#       2 m = 1
# ----> 3 df = fix_df(df,i, m)
#
# ~\AppData\Local\Temp\ipykernel_20684\2971180992.py in fix_df(df, j, k)
#       1 def fix_df(df, j , k):
# ----> 2     if ((df['path'][j]) == (df['path'][j+k])):
#       3         if ((df['x_max'][j]-df['x_min'][j])*(df['y_max'][j]-df['y_min'][j])) >=  ((df['x_max'][j+k]-df['x_min'][j+k])*(df['y_max'][j+k]-df['y_min'][j+k])):
#       4             df.drop(0,j+k, inplace = True)
#       5             k = k+1
#
# D:\Users\chano\Anaconda2\envs\tf-gpu\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#    1062         key = com.apply_if_callable(key, self)
#    1063         try:
# -> 1064             result = self.index.get_value(self, key)
#    1065
# ...

# %%
def fix_df(dframe, j , k):
    if ((dframe['path'][j]) == (dframe['path'][j+k])):
        if ((dframe['x_max'][j]-dframe['x_min'][j])*(dframe['y_max'][j]-dframe['y_min'][j])) >=  ((dframe['x_max'][j+k]-dframe['x_min'][j+k])*(dframe['y_max'][j+k]-dframe['y_min'][j+k])):
            dframe.drop(0,j+k, inplace = True)
            k = k+1
            dframe = fix_df(dframe,j, k)            

        else :
            dframe.drop(0,j, inplace = True)
            j = j + 1
            k = 1
            dframe = fix_df(dframe,j, k)            
    else: 
        j = j+1
        k = 1
        dframe = fix_df(dframe,j, k)
    return dframe

# %%
i = 1,
m = 1
df = fix_df(df,i, m)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20684\1334435729.py in <module>
#       1 i = 0,
#       2 m = 1
# ----> 3 df = fix_df(df,i, m)
#
# ~\AppData\Local\Temp\ipykernel_20684\4225891690.py in fix_df(dframe, j, k)
#       1 def fix_df(dframe, j , k):
# ----> 2     if ((dframe['path'][j]) == (dframe['path'][j+k])):
#       3         if ((dframe['x_max'][j]-dframe['x_min'][j])*(dframe['y_max'][j]-dframe['y_min'][j])) >=  ((dframe['x_max'][j+k]-dframe['x_min'][j+k])*(dframe['y_max'][j+k]-dframe['y_min'][j+k])):
#       4             dframe.drop(0,j+k, inplace = True)
#       5             k = k+1
#
# D:\Users\chano\Anaconda2\envs\tf-gpu\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#    1062         key = com.apply_if_callable(key, self)
#    1063         try:
# ...

# %%
i = 1
k = 1
a = 5093-1 # is number of images in folders
while i < a:
    if ((df['path'][i]) == (df['path'][i+k])):
        if ((df['x_max'][i]-df['x_min'][i])*(df['y_max'][i]-df['y_min'][i])) >=  ((df['x_max'][i+k]-df['x_min'][i+k])*(df['y_max'][i+k]-df['y_min'][i+k])):
            df.drop(0,i+k, inplace = True)
            a = a - 1
            k = k+1
            continue
        else :
            df.drop(0,i, inplace = True)
            a = a - 1
            continue          
    else: 
        i = i+1
        k = 1
        continue
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20684\1403179468.py in <module>
#       3 a = 5093-1 # is number of images in folders
#       4 while i < a:
# ----> 5     if ((df['path'][i]) == (df['path'][i+k])):
#       6         if ((df['x_max'][i]-df['x_min'][i])*(df['y_max'][i]-df['y_min'][i])) >=  ((df['x_max'][i+k]-df['x_min'][i+k])*(df['y_max'][i+k]-df['y_min'][i+k])):
#       7             df.drop(0,i+k, inplace = True)
#
# D:\Users\chano\Anaconda2\envs\tf-gpu\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#    1062         key = com.apply_if_callable(key, self)
#    1063         try:
# -> 1064             result = self.index.get_value(self, key)
#    1065
#    1066             if not is_scalar(result):
#
# ...

# %%
df['path'][i]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20684\2088131877.py in <module>
# ----> 1 df['path'][i]
#
# D:\Users\chano\Anaconda2\envs\tf-gpu\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#    1062         key = com.apply_if_callable(key, self)
#    1063         try:
# -> 1064             result = self.index.get_value(self, key)
#    1065
#    1066             if not is_scalar(result):
#
# D:\Users\chano\Anaconda2\envs\tf-gpu\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    4721         k = self._convert_scalar_indexer(k, kind="getitem")
#    4722         try:
# -> 4723             return self._engine.get_value(s, k, tz=getattr(series.dtype, "tz", None))
#    4724         except KeyError as e1:
#    4725             if len(self) > 0 and (self.holds_integer() or self.is_boolean()):
#
# ...

# %%
df
# Out:
#          label  occluded       x_max       x_min       y_max       y_min  \
# 1       Yellow     False  638.125000  633.875000  351.000000  342.250000
# 2       Yellow     False  655.000000  649.500000  360.750000  350.375000
# 3      RedLeft      True  615.500000  612.000000  360.375000  354.750000
# 4          Red     False  636.625000  632.250000  355.375000  346.375000
# 5          Red     False  653.875000  649.250000  364.875000  353.500000
# ...        ...       ...         ...         ...         ...         ...
# 10751    Green     False  590.047547  573.580846  219.137754  175.765818
# 10752    Green     False  544.689352  508.938214   71.680937    1.331923
# 10753    Green     False  892.943457  861.151823  224.574408  154.392877
# 10754    Green     False  582.341789  573.372644  276.627118  256.311463
# 10755    Green     False  517.626782  510.027687  273.164089  256.427986
#
#                                                     path
# ...

# %%
i = 1,
m = 1
df = fix_df(df,i, m)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20684\250007048.py in <module>
#       1 i = 1,
#       2 m = 1
# ----> 3 df = fix_df(df,i, m)
#
# ~\AppData\Local\Temp\ipykernel_20684\4225891690.py in fix_df(dframe, j, k)
#       1 def fix_df(dframe, j , k):
# ----> 2     if ((dframe['path'][j]) == (dframe['path'][j+k])):
#       3         if ((dframe['x_max'][j]-dframe['x_min'][j])*(dframe['y_max'][j]-dframe['y_min'][j])) >=  ((dframe['x_max'][j+k]-dframe['x_min'][j+k])*(dframe['y_max'][j+k]-dframe['y_min'][j+k])):
#       4             dframe.drop(0,j+k, inplace = True)
#       5             k = k+1
#
# D:\Users\chano\Anaconda2\envs\tf-gpu\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#    1062         key = com.apply_if_callable(key, self)
#    1063         try:
# -> 1064             result = self.index.get_value(self, key)
# ...

# %%
df
# Out:
#          label  occluded       x_max       x_min       y_max       y_min  \
# 1       Yellow     False  638.125000  633.875000  351.000000  342.250000
# 2       Yellow     False  655.000000  649.500000  360.750000  350.375000
# 3      RedLeft      True  615.500000  612.000000  360.375000  354.750000
# 4          Red     False  636.625000  632.250000  355.375000  346.375000
# 5          Red     False  653.875000  649.250000  364.875000  353.500000
# ...        ...       ...         ...         ...         ...         ...
# 10751    Green     False  590.047547  573.580846  219.137754  175.765818
# 10752    Green     False  544.689352  508.938214   71.680937    1.331923
# 10753    Green     False  892.943457  861.151823  224.574408  154.392877
# 10754    Green     False  582.341789  573.372644  276.627118  256.311463
# 10755    Green     False  517.626782  510.027687  273.164089  256.427986
#
#                                                     path
# ...

# %%
i = 1
k = 1
a = 5093-1 # is number of images in folders
while i < a:
    if ((df['path'][i]) == (df['path'][i+k])):
        if ((df['x_max'][i]-df['x_min'][i])*(df['y_max'][i]-df['y_min'][i])) >=  ((df['x_max'][i+k]-df['x_min'][i+k])*(df['y_max'][i+k]-df['y_min'][i+k])):
            df.drop(0,i+k, inplace = True)
            a = a - 1
            k = k+1
            continue
        else :
            df.drop(0,i, inplace = True)
            a = a - 1
            continue          
    else: 
        i = i+1
        k = 1
        continue
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20684\2070187979.py in <module>
#      10             continue
#      11         else :
# ---> 12             df.drop(0,i, inplace = True)
#      13             a = a - 1
#      14             continue
#
# D:\Users\chano\Anaconda2\envs\tf-gpu\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4095             level=level,
#    4096             inplace=inplace,
# -> 4097             errors=errors,
#    4098         )
#    4099
#
# D:\Users\chano\Anaconda2\envs\tf-gpu\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3913         for axis, labels in axes.items():
#    3914             if labels is not None:
# ...

# %%
df
# Out:
#          label  occluded       x_max       x_min       y_max       y_min  \
# 1       Yellow     False  638.125000  633.875000  351.000000  342.250000
# 2       Yellow     False  655.000000  649.500000  360.750000  350.375000
# 3      RedLeft      True  615.500000  612.000000  360.375000  354.750000
# 4          Red     False  636.625000  632.250000  355.375000  346.375000
# 5          Red     False  653.875000  649.250000  364.875000  353.500000
# ...        ...       ...         ...         ...         ...         ...
# 10751    Green     False  590.047547  573.580846  219.137754  175.765818
# 10752    Green     False  544.689352  508.938214   71.680937    1.331923
# 10753    Green     False  892.943457  861.151823  224.574408  154.392877
# 10754    Green     False  582.341789  573.372644  276.627118  256.311463
# 10755    Green     False  517.626782  510.027687  273.164089  256.427986
#
#                                                     path
# ...

# %%
df.drop(0,1, inplace= true)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20684\2690552154.py in <module>
# ----> 1 df.drop(0,1, inplace= true)
#
# NameError: name 'true' is not defined

# %%
df.drop(0,1, inplace= True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20684\923818263.py in <module>
# ----> 1 df.drop(0,1, inplace= True)
#
# D:\Users\chano\Anaconda2\envs\tf-gpu\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4095             level=level,
#    4096             inplace=inplace,
# -> 4097             errors=errors,
#    4098         )
#    4099
#
# D:\Users\chano\Anaconda2\envs\tf-gpu\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3913         for axis, labels in axes.items():
#    3914             if labels is not None:
# -> 3915                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3916
#    3917         if inplace:
#
# ...

# %%
df.drop(1, inplace= True)

# %%
df
# Out:
#          label  occluded       x_max       x_min       y_max       y_min  \
# 2       Yellow     False  655.000000  649.500000  360.750000  350.375000
# 3      RedLeft      True  615.500000  612.000000  360.375000  354.750000
# 4          Red     False  636.625000  632.250000  355.375000  346.375000
# 5          Red     False  653.875000  649.250000  364.875000  353.500000
# 6      RedLeft     False  613.625000  608.875000  364.750000  354.000000
# ...        ...       ...         ...         ...         ...         ...
# 10751    Green     False  590.047547  573.580846  219.137754  175.765818
# 10752    Green     False  544.689352  508.938214   71.680937    1.331923
# 10753    Green     False  892.943457  861.151823  224.574408  154.392877
# 10754    Green     False  582.341789  573.372644  276.627118  256.311463
# 10755    Green     False  517.626782  510.027687  273.164089  256.427986
#
#                                                     path
# ...

# %%
i = 1
k = 1
a = 5093-1 # is number of images in folders
while i < a:
    if ((df['path'][i]) == (df['path'][i+k])):
        if ((df['x_max'][i]-df['x_min'][i])*(df['y_max'][i]-df['y_min'][i])) >=  ((df['x_max'][i+k]-df['x_min'][i+k])*(df['y_max'][i+k]-df['y_min'][i+k])):
            df.drop(i+k, inplace = True)
            a = a - 1
            k = k+1
            continue
        else :
            df.drop(i, inplace = True)
            a = a - 1
            continue          
    else: 
        i = i+1
        k = 1
        continue
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20684\30427608.py in <module>
#       3 a = 5093-1 # is number of images in folders
#       4 while i < a:
# ----> 5     if ((df['path'][i]) == (df['path'][i+k])):
#       6         if ((df['x_max'][i]-df['x_min'][i])*(df['y_max'][i]-df['y_min'][i])) >=  ((df['x_max'][i+k]-df['x_min'][i+k])*(df['y_max'][i+k]-df['y_min'][i+k])):
#       7             df.drop(i+k, inplace = True)
#
# D:\Users\chano\Anaconda2\envs\tf-gpu\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#    1062         key = com.apply_if_callable(key, self)
#    1063         try:
# -> 1064             result = self.index.get_value(self, key)
#    1065
#    1066             if not is_scalar(result):
#
# D:\Users\chano\Anaconda2\envs\tf-gpu\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
# ...

# %%
i
# Out:
# 1

# %%
i = 2
k = 1
a = 5093-1 # is number of images in folders
while i < a:
    if ((df['path'][i]) == (df['path'][i+k])):
        if ((df['x_max'][i]-df['x_min'][i])*(df['y_max'][i]-df['y_min'][i])) >=  ((df['x_max'][i+k]-df['x_min'][i+k])*(df['y_max'][i+k]-df['y_min'][i+k])):
            df.drop(i+k, inplace = True)
            a = a - 1
            k = k+1
            continue
        else :
            df.drop(i, inplace = True)
            a = a - 1
            continue          
    else: 
        i = i+1
        k = 1
        continue
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20684\2079199685.py in <module>
#      10             continue
#      11         else :
# ---> 12             df.drop(0,i, inplace = True)
#      13             a = a - 1
#      14             continue
#
# D:\Users\chano\Anaconda2\envs\tf-gpu\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4095             level=level,
#    4096             inplace=inplace,
# -> 4097             errors=errors,
#    4098         )
#    4099
#
# D:\Users\chano\Anaconda2\envs\tf-gpu\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3900                     "Cannot specify both 'labels' and " "'index'/'columns'"
#    3901                 )
# ...

# %%
i = 2
k = 1
a = 5093-1 # is number of images in folders
while i < a:
    if ((df['path'][i]) == (df['path'][i+k])):
        if ((df['x_max'][i]-df['x_min'][i])*(df['y_max'][i]-df['y_min'][i])) >=  ((df['x_max'][i+k]-df['x_min'][i+k])*(df['y_max'][i+k]-df['y_min'][i+k])):
            df.drop(i+k, inplace = True)
            a = a - 1
            k = k+1
            continue
        else :
            df.drop(i, inplace = True)
            a = a - 1
            continue          
    else: 
        i = i+1
        k = 1
        continue
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20684\115482138.py in <module>
#       3 a = 5093-1 # is number of images in folders
#       4 while i < a:
# ----> 5     if ((df['path'][i]) == (df['path'][i+k])):
#       6         if ((df['x_max'][i]-df['x_min'][i])*(df['y_max'][i]-df['y_min'][i])) >=  ((df['x_max'][i+k]-df['x_min'][i+k])*(df['y_max'][i+k]-df['y_min'][i+k])):
#       7             df.drop(i+k, inplace = True)
#
# D:\Users\chano\Anaconda2\envs\tf-gpu\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#    1062         key = com.apply_if_callable(key, self)
#    1063         try:
# -> 1064             result = self.index.get_value(self, key)
#    1065
#    1066             if not is_scalar(result):
#
# D:\Users\chano\Anaconda2\envs\tf-gpu\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
# ...

# %%
df
# Out:
#          label  occluded       x_max       x_min       y_max       y_min  \
# 2       Yellow     False  655.000000  649.500000  360.750000  350.375000
# 4          Red     False  636.625000  632.250000  355.375000  346.375000
# 5          Red     False  653.875000  649.250000  364.875000  353.500000
# 6      RedLeft     False  613.625000  608.875000  364.750000  354.000000
# 7          Red     False  638.000000  633.125000  353.875000  343.375000
# ...        ...       ...         ...         ...         ...         ...
# 10751    Green     False  590.047547  573.580846  219.137754  175.765818
# 10752    Green     False  544.689352  508.938214   71.680937    1.331923
# 10753    Green     False  892.943457  861.151823  224.574408  154.392877
# 10754    Green     False  582.341789  573.372644  276.627118  256.311463
# 10755    Green     False  517.626782  510.027687  273.164089  256.427986
#
#                                                     path
# ...

# %%
import yaml
import pandas as pd
with open('train.yaml', 'r') as f:
    df = pd.io.json.json_normalize(yaml.load(f, Loader=yaml.FullLoader),'boxes', 'path' )

# %%
df
# Out:
#          label  occluded       x_max       x_min       y_max       y_min  \
# 0       Yellow      True  615.750000  610.625000  358.625000  351.500000
# 1       Yellow     False  638.125000  633.875000  351.000000  342.250000
# 2       Yellow     False  655.000000  649.500000  360.750000  350.375000
# 3      RedLeft      True  615.500000  612.000000  360.375000  354.750000
# 4          Red     False  636.625000  632.250000  355.375000  346.375000
# ...        ...       ...         ...         ...         ...         ...
# 10751    Green     False  590.047547  573.580846  219.137754  175.765818
# 10752    Green     False  544.689352  508.938214   71.680937    1.331923
# 10753    Green     False  892.943457  861.151823  224.574408  154.392877
# 10754    Green     False  582.341789  573.372644  276.627118  256.311463
# 10755    Green     False  517.626782  510.027687  273.164089  256.427986
#
#                                                     path
# ...

# %%
i = 0
k = 1
a = 5093-1 # is number of images in folders
while i < a:
    if ((df['path'][i]) == (df['path'][i+k])):
        if ((df['x_max'][i]-df['x_min'][i])*(df['y_max'][i]-df['y_min'][i])) >=  ((df['x_max'][i+k]-df['x_min'][i+k])*(df['y_max'][i+k]-df['y_min'][i+k])):
            df.drop(i+k, inplace = True)
            #a = a - 1
            k = k+1
            continue
        else :
            df.drop(i, inplace = True)
            #a = a - 1
            i = i +1
            k = 1
            continue          
    else: 
        i = i+1
        k = 1
        continue
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20684\3825191404.py in <module>
#       3 a = 5093-1 # is number of images in folders
#       4 while i < a:
# ----> 5     if ((df['path'][i]) == (df['path'][i+k])):
#       6         if ((df['x_max'][i]-df['x_min'][i])*(df['y_max'][i]-df['y_min'][i])) >=  ((df['x_max'][i+k]-df['x_min'][i+k])*(df['y_max'][i+k]-df['y_min'][i+k])):
#       7             df.drop(i+k, inplace = True)
#
# D:\Users\chano\Anaconda2\envs\tf-gpu\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#    1062         key = com.apply_if_callable(key, self)
#    1063         try:
# -> 1064             result = self.index.get_value(self, key)
#    1065
#    1066             if not is_scalar(result):
#
# D:\Users\chano\Anaconda2\envs\tf-gpu\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
# ...

# %%
df
# Out:
#          label  occluded       x_max       x_min       y_max       y_min  \
# 2       Yellow     False  655.000000  649.500000  360.750000  350.375000
# 5          Red     False  653.875000  649.250000  364.875000  353.500000
# 7          Red     False  638.000000  633.125000  353.875000  343.375000
# 9          Red     False  640.000000  633.000000  355.625000  344.250000
# 10     RedLeft      True  615.000000  610.000000  365.000000  356.500000
# ...        ...       ...         ...         ...         ...         ...
# 10751    Green     False  590.047547  573.580846  219.137754  175.765818
# 10752    Green     False  544.689352  508.938214   71.680937    1.331923
# 10753    Green     False  892.943457  861.151823  224.574408  154.392877
# 10754    Green     False  582.341789  573.372644  276.627118  256.311463
# 10755    Green     False  517.626782  510.027687  273.164089  256.427986
#
#                                                     path
# ...

# %%
i
# Out:
# 8

# %%
import yaml
import pandas as pd
with open('train.yaml', 'r') as f:
    df = pd.io.json.json_normalize(yaml.load(f, Loader=yaml.FullLoader),'boxes', 'path' )

# %%
df
# Out:
#          label  occluded       x_max       x_min       y_max       y_min  \
# 0       Yellow      True  615.750000  610.625000  358.625000  351.500000
# 1       Yellow     False  638.125000  633.875000  351.000000  342.250000
# 2       Yellow     False  655.000000  649.500000  360.750000  350.375000
# 3      RedLeft      True  615.500000  612.000000  360.375000  354.750000
# 4          Red     False  636.625000  632.250000  355.375000  346.375000
# ...        ...       ...         ...         ...         ...         ...
# 10751    Green     False  590.047547  573.580846  219.137754  175.765818
# 10752    Green     False  544.689352  508.938214   71.680937    1.331923
# 10753    Green     False  892.943457  861.151823  224.574408  154.392877
# 10754    Green     False  582.341789  573.372644  276.627118  256.311463
# 10755    Green     False  517.626782  510.027687  273.164089  256.427986
#
#                                                     path
# ...

# %%
i = 0
k = 1
a = 5093-1 # is number of images in folders
while df.shape[0] >= 5092:
    if ((df['path'][i]) == (df['path'][k])):
        if ((df['x_max'][i]-df['x_min'][i])*(df['y_max'][i]-df['y_min'][i])) >=  ((df['x_max'][k]-df['x_min'][k])*(df['y_max'][k]-df['y_min'][k])):
            df.drop(k, inplace = True)
            #a = a - 1
            k = k+1
            continue
        else :
            df.drop(i, inplace = True)
            #a = a - 1
            i = k
            k = i+1
            continue          
    else: 
        i = k
        k = i+1
        continue

# %%
df
# Out:
#         label  occluded       x_max       x_min       y_max       y_min  \
# 2      Yellow     False  655.000000  649.500000  360.750000  350.375000
# 5         Red     False  653.875000  649.250000  364.875000  353.500000
# 7         Red     False  638.000000  633.125000  353.875000  343.375000
# 11        Red     False  659.500000  651.875000  366.375000  353.750000
# 13        Red     False  639.750000  633.125000  350.250000  340.250000
# ...       ...       ...         ...         ...         ...         ...
# 10751   Green     False  590.047547  573.580846  219.137754  175.765818
# 10752   Green     False  544.689352  508.938214   71.680937    1.331923
# 10753   Green     False  892.943457  861.151823  224.574408  154.392877
# 10754   Green     False  582.341789  573.372644  276.627118  256.311463
# 10755   Green     False  517.626782  510.027687  273.164089  256.427986
#
#                                                     path
# ...

# %%
df.shape(0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20684\2903373755.py in <module>
# ----> 1 df.shape(0)
#
# TypeError: 'tuple' object is not callable

# %%
df.shape[0]
# Out:
# 7060

# %%
import yaml
import pandas as pd
with open('train.yaml', 'r') as f:
    df = pd.io.json.json_normalize(yaml.load(f, Loader=yaml.FullLoader),'boxes', 'path' )

# %%
import yaml
import pandas as pd
with open('train.yaml', 'r') as f:
    df = pd.io.json.json_normalize(yaml.load(f, Loader=yaml.FullLoader),'boxes', 'path' )

# %%
i = 0
k = 1
a = 5093-1 # is number of images in folders
while df.shape[0] >= 5092:
    if ((df['path'][i]) == (df['path'][k])):
        if ((df['x_max'][i]-df['x_min'][i])*(df['y_max'][i]-df['y_min'][i])) >=  ((df['x_max'][k]-df['x_min'][k])*(df['y_max'][k]-df['y_min'][k])):
            df.drop(k, inplace = True)
            #a = a - 1
            k = k+1
            continue
        else :
            df.drop(i, inplace = True)
            #a = a - 1
            i = k
            k = i+1
            continue          
    else: 
        i = k
        k = i+1
        continue

# %%
i = 0
k = 1
a = 5093 # is number of images in folders
while df.shape[0] >= a:
    if ((df['path'][i]) == (df['path'][k])):
        if ((df['x_max'][i]-df['x_min'][i])*(df['y_max'][i]-df['y_min'][i])) >=  ((df['x_max'][k]-df['x_min'][k])*(df['y_max'][k]-df['y_min'][k])):
            df.drop(k, inplace = True)
            #a = a - 1
            k = k+1
            continue
        else :
            df.drop(i, inplace = True)
            #a = a - 1
            i = k
            k = i+1
            continue          
    else: 
        i = k
        k = i+1
        continue

# %%
df
# Out:
#         label  occluded       x_max       x_min       y_max       y_min  \
# 2      Yellow     False  655.000000  649.500000  360.750000  350.375000
# 5         Red     False  653.875000  649.250000  364.875000  353.500000
# 7         Red     False  638.000000  633.125000  353.875000  343.375000
# 11        Red     False  659.500000  651.875000  366.375000  353.750000
# 13        Red     False  639.750000  633.125000  350.250000  340.250000
# ...       ...       ...         ...         ...         ...         ...
# 10751   Green     False  590.047547  573.580846  219.137754  175.765818
# 10752   Green     False  544.689352  508.938214   71.680937    1.331923
# 10753   Green     False  892.943457  861.151823  224.574408  154.392877
# 10754   Green     False  582.341789  573.372644  276.627118  256.311463
# 10755   Green     False  517.626782  510.027687  273.164089  256.427986
#
#                                                     path
# ...

# %%
df.to_csv('train.csv',index=False)

# %%
df['path']
# Out:
# 2        ./rgb/train/2017-02-03-11-44-56_los_altos_moun...
# 5        ./rgb/train/2017-02-03-11-44-56_los_altos_moun...
# 7        ./rgb/train/2017-02-03-11-44-56_los_altos_moun...
# 11       ./rgb/train/2017-02-03-11-44-56_los_altos_moun...
# 13       ./rgb/train/2017-02-03-11-44-56_los_altos_moun...
#                                ...
# 10751       ./rgb/train/2015-10-05-16-02-30_bag/720238.png
# 10752       ./rgb/train/2015-10-05-16-02-30_bag/720308.png
# 10753       ./rgb/train/2015-10-05-16-02-30_bag/720308.png
# 10754       ./rgb/train/2015-10-05-16-02-30_bag/720654.png
# 10755       ./rgb/train/2015-10-05-16-02-30_bag/720654.png
# Name: path, Length: 5091, dtype: object

# %%
a.split('\\')[-2] a.split('\\')[-1]

# %%
import numpy as np
from skimage import color, exposure, transform 
import  skimage
from skimage.color import rgb2gray
from skimage.filters import sobel_h
import skimage.color
import skimage.filters
from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Activation, Flatten
from keras.layers.convolutional import Conv2D
from keras.layers.pooling import MaxPooling2D
from keras.optimizers import SGD
from keras import backend as K
K.set_image_data_format('channels_first')
from skimage.transform import rescale

from matplotlib.pyplot import figure, show
from sklearn.model_selection import train_test_split
import pandas as pd
import os
import numpy as np
from sklearn import metrics
from scipy.stats import zscore
import tensorflow as tf
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint
# Out:
# Using TensorFlow backend.

# %%
def preprocess_img(img):

    #img = rgb2gray(img)
    
    # thresholding and sobel filter
    #t = skimage.filters.threshold_otsu(img)
    #img = img > t

    #img = sobel_h(img)
    
    # top half crop
    #img = img[240:480,0:640]

    # downsample by 100
    img = rescale(img, scale=(0.1))
    
    # roll color to axis 0
    img = np.rollaxis(img, -1)

    return img

# %%
from skimage import io
import os
import glob




root_dir = 'dataset_train_riib/riib/train/'
imgs = []
labels = []

all_img_paths = glob.glob(os.path.join(root_dir, '*/*.pgm'))
i = 0
#np.random.shuffle(all_img_paths)
for img_path in all_img_paths:
    img = preprocess_img(io.imread(img_path))
    a = df.index[i] 
    i = i + 1
    label = df['label'][a]
    imgs.append(img)
    labels.append(label)

X = np.array(imgs, dtype='float32')
# Make one hot targets
Y = np.eye(NUM_CLASSES, dtype='uint8')[labels]

# %%
df.loc

# %%
df
# Out:
#         label  occluded       x_max       x_min       y_max       y_min  \
# 2      Yellow     False  655.000000  649.500000  360.750000  350.375000
# 5         Red     False  653.875000  649.250000  364.875000  353.500000
# 7         Red     False  638.000000  633.125000  353.875000  343.375000
# 11        Red     False  659.500000  651.875000  366.375000  353.750000
# 13        Red     False  639.750000  633.125000  350.250000  340.250000
# ...       ...       ...         ...         ...         ...         ...
# 10751   Green     False  590.047547  573.580846  219.137754  175.765818
# 10752   Green     False  544.689352  508.938214   71.680937    1.331923
# 10753   Green     False  892.943457  861.151823  224.574408  154.392877
# 10754   Green     False  582.341789  573.372644  276.627118  256.311463
# 10755   Green     False  517.626782  510.027687  273.164089  256.427986
#
#                                                     path
# ...

# %%
df.index
# Out:
# Int64Index([    2,     5,     7,    11,    13,    17,    19,    22,    25,
#                27,
#             ...
#             10746, 10747, 10748, 10749, 10750, 10751, 10752, 10753, 10754,
#             10755],
#            dtype='int64', length=5091)

# %%
df.index[1]
# Out:
# 5

# %%
a = df.index[1]

# %%
a
# Out:
# 5

# %%
df['label'][a]
# Out:
# 'Red'

# %%
a = df.index[1] df['label'][a]

# %%
from skimage import io
import os
import glob




root_dir = 'dataset_train_riib/riib/train/'
imgs = []
labels = []

all_img_paths = glob.glob(os.path.join(root_dir, '*/*.pgm'))
i = 0
#np.random.shuffle(all_img_paths)
for img_path in all_img_paths:
    img = preprocess_img(io.imread(img_path))
    a = df.index[i] 
    i = i + 1
    label = df['label'][a]
    imgs.append(img)
    labels.append(label)

X = np.array(imgs, dtype='float32')
# Make one hot targets
Y = np.eye(NUM_CLASSES, dtype='uint8')[labels]
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "D:\Users\chano\Anaconda2\envs\tf-gpu\lib\site-packages\IPython\core\interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\chano\AppData\Local\Temp\ipykernel_20684\183095409.py", line 17, in <module>
#     a = df.index[i]
#   File "D:\Users\chano\Anaconda2\envs\tf-gpu\lib\site-packages\pandas\core\indexes\base.py", line 4273, in __getitem__
#     return getitem(key)
# IndexError: index 5091 is out of bounds for axis 0 with size 5091
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
# ...

# %%
X
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "D:\Users\chano\Anaconda2\envs\tf-gpu\lib\site-packages\IPython\core\interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\chano\AppData\Local\Temp\ipykernel_20684\3777217377.py", line 1, in <module>
#     X
# NameError: name 'X' is not defined
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "D:\Users\chano\Anaconda2\envs\tf-gpu\lib\site-packages\IPython\core\interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# ...

# %%
from skimage import io
import os
import glob




root_dir = 'dataset_train_riib/riib/train/'
imgs = []
labels = []

all_img_paths = glob.glob(os.path.join(root_dir, '*/*.pgm'))
i = 0
#np.random.shuffle(all_img_paths)
for img_path in all_img_paths:
    img = preprocess_img(io.imread(img_path))
    a = df.index[i] 
    i = i + 1
    label = df['label'][a]
    imgs.append(img)
    labels.append(label)


X = np.array(imgs, dtype='float32')
# Make one hot targets
Y = labels
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session 243
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "D:\Users\chano\Anaconda2\envs\tf-gpu\lib\site-packages\IPython\core\interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\chano\AppData\Local\Temp\ipykernel_20684\2144273315.py", line 17, in <module>
#     a = df.index[i]
#   File "D:\Users\chano\Anaconda2\envs\tf-gpu\lib\site-packages\pandas\core\indexes\base.py", line 4273, in __getitem__
#     return getitem(key)
# IndexError: index 5091 is out of bounds for axis 0 with size 5091
#
# ...

# %%
X
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "D:\Users\chano\Anaconda2\envs\tf-gpu\lib\site-packages\IPython\core\interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\chano\AppData\Local\Temp\ipykernel_20684\3777217377.py", line 1, in <module>
#     X
# NameError: name 'X' is not defined
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "D:\Users\chano\Anaconda2\envs\tf-gpu\lib\site-packages\IPython\core\interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# ...

# %%
all_img_paths
# Out:
# ['dataset_train_riib/riib/train\\2015-05-29-15-29-39_arastradero_traffic_light_loop_bag\\10648.pgm',
#  'dataset_train_riib/riib/train\\2015-05-29-15-29-39_arastradero_traffic_light_loop_bag\\10718.pgm',
#  'dataset_train_riib/riib/train\\2015-05-29-15-29-39_arastradero_traffic_light_loop_bag\\10786.pgm',
#  'dataset_train_riib/riib/train\\2015-05-29-15-29-39_arastradero_traffic_light_loop_bag\\10856.pgm',
#  'dataset_train_riib/riib/train\\2015-05-29-15-29-39_arastradero_traffic_light_loop_bag\\10926.pgm',
#  'dataset_train_riib/riib/train\\2015-05-29-15-29-39_arastradero_traffic_light_loop_bag\\10996.pgm',
#  'dataset_train_riib/riib/train\\2015-05-29-15-29-39_arastradero_traffic_light_loop_bag\\11064.pgm',
#  'dataset_train_riib/riib/train\\2015-05-29-15-29-39_arastradero_traffic_light_loop_bag\\11134.pgm',
#  'dataset_train_riib/riib/train\\2015-05-29-15-29-39_arastradero_traffic_light_loop_bag\\11204.pgm',
# ...

# %%
all_img_paths.shape
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "D:\Users\chano\Anaconda2\envs\tf-gpu\lib\site-packages\IPython\core\interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\chano\AppData\Local\Temp\ipykernel_20684\4198532428.py", line 1, in <module>
#     all_img_paths.shape
# AttributeError: 'list' object has no attribute 'shape'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "D:\Users\chano\Anaconda2\envs\tf-gpu\lib\site-packages\IPython\core\interactiveshell.py", line 2077, in showtraceback
# ...

# %%
length(all_img_paths)
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "D:\Users\chano\Anaconda2\envs\tf-gpu\lib\site-packages\IPython\core\interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\chano\AppData\Local\Temp\ipykernel_20684\465937286.py", line 1, in <module>
#     length(all_img_paths)
# NameError: name 'length' is not defined
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "D:\Users\chano\Anaconda2\envs\tf-gpu\lib\site-packages\IPython\core\interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# ...

# %%
len(all_img_paths)
# Out:
# 5093
# ERROR! Session/line number was not unique in database. History logging moved to new session 247

# %%
all_img_paths(0)
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "D:\Users\chano\Anaconda2\envs\tf-gpu\lib\site-packages\IPython\core\interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\chano\AppData\Local\Temp\ipykernel_20684\1317191900.py", line 1, in <module>
#     all_img_paths(0)
# TypeError: 'list' object is not callable
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "D:\Users\chano\Anaconda2\envs\tf-gpu\lib\site-packages\IPython\core\interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# ...

# %%
all_img_paths[0]
# Out:
# 'dataset_train_riib/riib/train\\2015-05-29-15-29-39_arastradero_traffic_light_loop_bag\\10648.pgm'
# ERROR! Session/line number was not unique in database. History logging moved to new session 248

# %%
all_img_paths[5093]
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "D:\Users\chano\Anaconda2\envs\tf-gpu\lib\site-packages\IPython\core\interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\chano\AppData\Local\Temp\ipykernel_20684\566257206.py", line 1, in <module>
#     all_img_paths[5093]
# IndexError: list index out of range
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "D:\Users\chano\Anaconda2\envs\tf-gpu\lib\site-packages\IPython\core\interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# ...

# %%
all_img_paths[5092]
# Out:
# 'dataset_train_riib/riib/train\\2017-02-03-11-44-56_los_altos_mountain_view_traffic_lights_bag\\238920.pgm'
# ERROR! Session/line number was not unique in database. History logging moved to new session 249

# %%
i = 0
k = 1
a = 5093 # is number of images in folders
while df.shape[0] >= a:
    if ((df['path'][i]) == (df['path'][k])):
        if ((df['x_max'][i]-df['x_min'][i])*(df['y_max'][i]-df['y_min'][i])) >=  ((df['x_max'][k]-df['x_min'][k])*(df['y_max'][k]-df['y_min'][k])):
            df.drop(k, inplace = True)
            #a = a - 1
            k = k+1
            continue
        else :
            df.drop(i, inplace = True)
            #a = a - 1
            i = k
            k = i+1
            continue          
    else: 
        i = k
        k = i+1
        continue

# %%
from skimage import io
import os
import glob




root_dir = 'dataset_train_riib/riib/train/'
imgs = []
labels = []

all_img_paths = glob.glob(os.path.join(root_dir, '*/*.pgm'))
i = 0
#np.random.shuffle(all_img_paths)
for img_path in all_img_paths:
    img = preprocess_img(io.imread(img_path))
    a = df.index[i] 
    i = i + 1
    label = df['label'][a]
    imgs.append(img)
    labels.append(label)


X = np.array(imgs, dtype='float32')
# Make one hot targets
Y = labels
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "D:\Users\chano\Anaconda2\envs\tf-gpu\lib\site-packages\IPython\core\interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\chano\AppData\Local\Temp\ipykernel_20684\2144273315.py", line 17, in <module>
#     a = df.index[i]
#   File "D:\Users\chano\Anaconda2\envs\tf-gpu\lib\site-packages\pandas\core\indexes\base.py", line 4273, in __getitem__
#     return getitem(key)
# IndexError: index 5092 is out of bounds for axis 0 with size 5092
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
# ...

# %%
imgs
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session 250
# [array([[4.27824503e-07, 7.51600817e-07, 7.48021890e-07, ...,
#          3.52186534e-07, 3.32270363e-07, 3.98188956e-07],
#         [3.89992627e-07, 7.18177703e-07, 7.61049665e-07, ...,
#          3.70352762e-07, 3.44538643e-07, 4.76462835e-07],
#         [3.93526817e-07, 7.06975443e-07, 7.60312720e-07, ...,
#          3.78250362e-07, 3.50843078e-07, 3.65447655e-07],
#         ...,
#         [4.00645907e-07, 8.22916121e-07, 8.24607654e-07, ...,
#          3.62705898e-07, 3.43269270e-07, 3.29132794e-07],
#         [3.95345455e-07, 7.96200998e-07, 7.91478099e-07, ...,
#          3.43705180e-07, 3.36403504e-07, 4.31142672e-07],
#         [3.91304448e-07, 7.90324453e-07, 7.69309595e-07, ...,
#          3.29782903e-07, 3.35153229e-07, 3.49524747e-07]]),
#  array([[4.27551252e-07, 7.07047439e-07, 7.08272908e-07, ...,
#          4.25812503e-07, 3.67676423e-07, 3.81495445e-07],
# ...

# %%
labels
# Out:
# ['Yellow',
#  'Red',
#  'Red',
#  'Red',
#  'Red',
#  'Red',
#  'Red',
#  'Red',
#  'Red',
#  'RedLeft',
#  'Red',
#  'Red',
#  'Red',
#  'Red',
#  'Red',
#  'Red',
#  'Red',
#  'RedLeft',
#  'RedLeft',
#  'RedLeft',
#  'RedLeft',
#  'RedLeft',
#  'RedLeft',
#  'RedLeft',
#  'GreenLeft',
#  'GreenLeft',
#  'GreenLeft',
#  'GreenLeft',
#  'GreenLeft',
#  'off',
#  'Green',
#  'off',
#  'off',
#  'Green',
#  'Green',
#  'Red',
#  'Red',
#  'Red',
#  'off',
#  'off',
#  'off',
#  'off',
#  'off',
#  'off',
#  'off',
#  'off',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Red',
#  'Red',
#  'Green',
#  'Red',
#  'Red',
#  'Red',
#  'Red',
#  'Red',
#  'Red',
#  'Red',
#  'Red',
#  'RedLeft',
#  'Red',
#  'off',
#  'off',
#  'off',
#  'Green',
#  'RedLeft',
#  'RedLeft',
#  'Red',
#  'Red',
#  'Red',
#  'Red',
#  'Red',
#  'Red',
#  'Red',
#  'Red',
#  'Red',
#  'Red',
#  'RedLeft',
#  'Red',
#  'Red',
#  'Red',
#  'RedLeft',
# ...

# %%
len(imgs)
# Out:
# 5092

# %%
len(labels)
# Out:
# 5092

# %%
X = np.array(imgs, dtype='float32')

# %%
Y = labels|
# Out:
#   File "C:\Users\chano\AppData\Local\Temp\ipykernel_20684\1355240886.py", line 1
#     Y = labels|
#                ^
# SyntaxError: invalid syntax

# %%
Y = labels

# %%
X
# Out:
# array([[[4.2782449e-07, 7.5160079e-07, 7.4802188e-07, ...,
#          3.5218653e-07, 3.3227036e-07, 3.9818894e-07],
#         [3.8999264e-07, 7.1817772e-07, 7.6104965e-07, ...,
#          3.7035275e-07, 3.4453865e-07, 4.7646284e-07],
#         [3.9352682e-07, 7.0697547e-07, 7.6031273e-07, ...,
#          3.7825035e-07, 3.5084307e-07, 3.6544765e-07],
#         ...,
#         [4.0064592e-07, 8.2291609e-07, 8.2460764e-07, ...,
#          3.6270589e-07, 3.4326928e-07, 3.2913280e-07],
#         [3.9534547e-07, 7.9620099e-07, 7.9147810e-07, ...,
#          3.4370518e-07, 3.3640350e-07, 4.3114267e-07],
#         [3.9130444e-07, 7.9032446e-07, 7.6930962e-07, ...,
#          3.2978289e-07, 3.3515323e-07, 3.4952475e-07]],
#
#        [[4.2755124e-07, 7.0704743e-07, 7.0827292e-07, ...,
#          4.2581252e-07, 3.6767642e-07, 3.8149545e-07],
#         [4.0376969e-07, 6.9850950e-07, 7.0874569e-07, ...,
#          4.3431476e-07, 3.4492041e-07, 4.3062104e-07],
# ...

# %% [markdown]
# ## from keras.models import Sequential
# from keras.layers.core import Dense, Dropout, Activation, Flatten
# from keras.layers.convolutional import Conv2D
# from keras.layers.pooling import MaxPooling2D
# from keras.optimizers import SGD
# from keras import backend as K
# K.set_image_data_format('channels_first')
#
#
# def cnn_model():
#     model = Sequential()
#
#     model.add(Conv2D(32, (3, 3), padding='same',
#                      input_shape=(3, IMG_SIZE, IMG_SIZE),
#                      activation='relu'))
#     model.add(Conv2D(32, (3, 3), activation='relu'))
#     model.add(MaxPooling2D(pool_size=(2, 2)))
#     model.add(Dropout(0.2))
#
#     model.add(Conv2D(64, (3, 3), padding='same',
#                      activation='relu'))
#     model.add(Conv2D(64, (3, 3), activation='relu'))
#     model.add(MaxPooling2D(pool_size=(2, 2)))
#     model.add(Dropout(0.2))
#
#     model.add(Conv2D(128, (3, 3), padding='same',
#                      activation='relu'))
#     model.add(Conv2D(128, (3, 3), activation='relu'))
#     model.add(MaxPooling2D(pool_size=(2, 2)))
#     model.add(Dropout(0.2))
#
#     model.add(Flatten())
#     model.add(Dense(512, activation='relu'))
#     model.add(Dropout(0.5))
#     model.add(Dense(10, activation='softmax'))
#     return model

# %%
from keras.optimizers import SGD

model = cnn_model()

# let's train the model using SGD + momentum
lr = 0.01
sgd = SGD(lr=lr, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy',
              optimizer=sgd,
              metrics=['accuracy'])
# Out:
# WARNING:tensorflow:From D:\Users\chano\Anaconda2\envs\tf-gpu\lib\site-packages\keras\backend\tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
# WARNING:tensorflow:From D:\Users\chano\Anaconda2\envs\tf-gpu\lib\site-packages\keras\backend\tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "D:\Users\chano\Anaconda2\envs\tf-gpu\lib\site-packages\IPython\core\interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
# ...

# %%
from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Activation, Flatten
from keras.layers.convolutional import Conv2D
from keras.layers.pooling import MaxPooling2D
from keras.optimizers import SGD
from keras import backend as K
K.set_image_data_format('channels_first')


def cnn_model():
    model = Sequential()

    model.add(Conv2D(32, (3, 3), padding='same',
                     input_shape=(3, 13, 8),
                     activation='relu'))
    model.add(Conv2D(32, (3, 3), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.2))

    model.add(Conv2D(64, (3, 3), padding='same',
                     activation='relu'))
    model.add(Conv2D(64, (3, 3), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.2))

    model.add(Conv2D(128, (3, 3), padding='same',
                     activation='relu'))
    model.add(Conv2D(128, (3, 3), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.2))

    model.add(Flatten())
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(6, activation='softmax'))
    return model
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session 251

# %%
from keras.optimizers import SGD

model = cnn_model()

# let's train the model using SGD + momentum
lr = 0.01
sgd = SGD(lr=lr, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy',
              optimizer=sgd,
              metrics=['accuracy'])
# Out:
# WARNING:tensorflow:From D:\Users\chano\Anaconda2\envs\tf-gpu\lib\site-packages\keras\backend\tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
# WARNING:tensorflow:From D:\Users\chano\Anaconda2\envs\tf-gpu\lib\site-packages\keras\backend\tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
# WARNING:tensorflow:From D:\Users\chano\Anaconda2\envs\tf-gpu\lib\site-packages\keras\backend\tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
# WARNING:tensorflow:From D:\Users\chano\Anaconda2\envs\tf-gpu\lib\site-packages\keras\backend\tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
# ...

# %%
from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Activation, Flatten
from keras.layers.convolutional import Conv2D
from keras.layers.pooling import MaxPooling2D
from keras.optimizers import SGD
from keras import backend as K
K.set_image_data_format('channels_first')


def cnn_model():
    model = Sequential()

    model.add(Conv2D(32, (3, 3), padding='same',
                     activation='relu'))
    model.add(Conv2D(32, (3, 3), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.2))

    model.add(Conv2D(64, (3, 3), padding='same',
                     activation='relu'))
    model.add(Conv2D(64, (3, 3), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.2))

    model.add(Conv2D(128, (3, 3), padding='same',
                     activation='relu'))
    model.add(Conv2D(128, (3, 3), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.2))

    model.add(Flatten())
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(6, activation='softmax'))
    return model
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session 252

# %%
from keras.optimizers import SGD

model = cnn_model()

# let's train the model using SGD + momentum
lr = 0.01
sgd = SGD(lr=lr, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy',
              optimizer=sgd,
              metrics=['accuracy'])
# Out:
# WARNING:tensorflow:From D:\Users\chano\Anaconda2\envs\tf-gpu\lib\site-packages\keras\optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
# WARNING:tensorflow:From D:\Users\chano\Anaconda2\envs\tf-gpu\lib\site-packages\keras\optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
from keras.callbacks import LearningRateScheduler, ModelCheckpoint


def lr_schedule(epoch):
    return lr * (0.1 ** int(epoch / 10))

batch_size = 32
epochs = 30

model.fit(X, Y,
          batch_size=batch_size,
          epochs=epochs,
          validation_split=0.2,
          callbacks=[LearningRateScheduler(lr_schedule),
                     ModelCheckpoint('model.h5', save_best_only=True)]
          )
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "D:\Users\chano\Anaconda2\envs\tf-gpu\lib\site-packages\IPython\core\interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\chano\AppData\Local\Temp\ipykernel_20684\2724808677.py", line 15, in <module>
#     ModelCheckpoint('model.h5', save_best_only=True)]
#   File "D:\Users\chano\Anaconda2\envs\tf-gpu\lib\site-packages\keras\engine\training.py", line 952, in fit
#     batch_size=batch_size)
#   File "D:\Users\chano\Anaconda2\envs\tf-gpu\lib\site-packages\keras\engine\training.py", line 677, in _standardize_user_data
#     self._set_inputs(x)
# ...

# %%
from keras.callbacks import LearningRateScheduler, ModelCheckpoint


def lr_schedule(epoch):
    return lr * (0.1 ** int(epoch / 10))

batch_size = 32
epochs = 30

model.fit(X, Y,
          batch_size=batch_size,
          epochs=epochs,
          validation_split=0.2,
          callbacks=[LearningRateScheduler(lr_schedule)]
          )
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "D:\Users\chano\Anaconda2\envs\tf-gpu\lib\site-packages\IPython\core\interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\chano\AppData\Local\Temp\ipykernel_20684\289633285.py", line 14, in <module>
#     callbacks=[LearningRateScheduler(lr_schedule)]
#   File "D:\Users\chano\Anaconda2\envs\tf-gpu\lib\site-packages\keras\engine\training.py", line 952, in fit
#     batch_size=batch_size)
#   File "D:\Users\chano\Anaconda2\envs\tf-gpu\lib\site-packages\keras\engine\training.py", line 693, in _standardize_user_data
#     'You passed: y=' + str(y))
# ...

# %%
# Make one hot targets
Y = np.eye(15, dtype='uint8')[labels]
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "D:\Users\chano\Anaconda2\envs\tf-gpu\lib\site-packages\IPython\core\interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\chano\AppData\Local\Temp\ipykernel_20684\2028252348.py", line 2, in <module>
#     Y = np.eye(15, dtype='uint8')[labels]
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
# ...

# %%
from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Activation, Flatten
from keras.layers.convolutional import Conv2D
from keras.layers.pooling import MaxPooling2D
from keras.optimizers import SGD
from keras import backend as K
K.set_image_data_format('channels_first')


def cnn_model():
    model = Sequential()

    model.add(Conv2D(32, (3, 3), padding='same',
                     activation='relu'))
    model.add(Conv2D(32, (3, 3), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.2))

    model.add(Conv2D(64, (3, 3), padding='same',
                     activation='relu'))
    model.add(Conv2D(64, (3, 3), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.2))

    model.add(Conv2D(128, (3, 3), padding='same',
                     activation='relu'))
    model.add(Conv2D(128, (3, 3), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.2))

    model.add(Flatten())
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(15, activation='softmax'))
    return model
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session 255

# %%
from keras.callbacks import LearningRateScheduler, ModelCheckpoint


def lr_schedule(epoch):
    return lr * (0.1 ** int(epoch / 10))

batch_size = 32
epochs = 30

model.fit(X, Y,
          batch_size=batch_size,
          epochs=epochs,
          validation_split=0.2,
          callbacks=[LearningRateScheduler(lr_schedule)]
          )
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "D:\Users\chano\Anaconda2\envs\tf-gpu\lib\site-packages\IPython\core\interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\chano\AppData\Local\Temp\ipykernel_20684\289633285.py", line 14, in <module>
#     callbacks=[LearningRateScheduler(lr_schedule)]
#   File "D:\Users\chano\Anaconda2\envs\tf-gpu\lib\site-packages\keras\engine\training.py", line 952, in fit
#     batch_size=batch_size)
#   File "D:\Users\chano\Anaconda2\envs\tf-gpu\lib\site-packages\keras\engine\training.py", line 693, in _standardize_user_data
#     'You passed: y=' + str(y))
# ...

# %%
# Convert a Pandas dataframe to the x,y inputs that TensorFlow needs
def to_xy(df, target):
    result = []
    for x in df.columns:
        if x != target:
            result.append(x)
    # find out the type of the target column.  Is it really this hard? :(
    target_type = df[target].dtypes
    target_type = target_type[0] if hasattr(target_type, '__iter__') else target_type
    # Encode to int for classification, float otherwise. TensorFlow likes 32 bits.
    if target_type in (np.int64, np.int32):
        # Classification
        dummies = pd.get_dummies(df[target])
        return df.as_matrix(result).astype(np.float32), dummies.as_matrix().astype(np.float32)
    else:
        # Regression
        return df.as_matrix(result).astype(np.float32), df.as_matrix([target]).astype(np.float32)
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session 258

# %%
X, Y = to_xy(X,Y)
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "D:\Users\chano\Anaconda2\envs\tf-gpu\lib\site-packages\IPython\core\interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\chano\AppData\Local\Temp\ipykernel_20684\2253020875.py", line 1, in <module>
#     X, Y = to_xy(X,Y)
#   File "C:\Users\chano\AppData\Local\Temp\ipykernel_20684\1731037100.py", line 4, in to_xy
#     for x in df.columns:
# AttributeError: 'numpy.ndarray' object has no attribute 'columns'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
# ...

# %%
import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras import backend as K

batch_size = 128
epochs = 12

num_classes = 4
Y = keras.utils.to_categorical(Y, num_classes)
model = Sequential()
model.add(Conv2D(32, kernel_size=(3, 3),
                 activation='relu',
                 input_shape=input_shape))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes, activation='softmax'))
model.compile(loss=keras.losses.categorical_crossentropy,
              optimizer=keras.optimizers.Adadelta(),
              metrics=['accuracy'])
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "D:\Users\chano\Anaconda2\envs\tf-gpu\lib\site-packages\IPython\core\interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\chano\AppData\Local\Temp\ipykernel_20684\677553625.py", line 2, in <module>
#     Y = keras.utils.to_categorical(Y, num_classes)
# NameError: name 'keras' is not defined
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "D:\Users\chano\Anaconda2\envs\tf-gpu\lib\site-packages\IPython\core\interactiveshell.py", line 2077, in showtraceback
# ...

# %%
import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras import backend as K

batch_size = 128
epochs = 12

num_classes = 4
Y = keras.utils.to_categorical(Y, num_classes)
model = Sequential()
model.add(Conv2D(32, kernel_size=(3, 3),
                 activation='relu',
                 input_shape=input_shape))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes, activation='softmax'))
model.compile(loss=keras.losses.categorical_crossentropy,
              optimizer=keras.optimizers.Adadelta(),
              metrics=['accuracy'])
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# ERROR! Session/line number was not unique in database. History logging moved to new session 262
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "D:\Users\chano\Anaconda2\envs\tf-gpu\lib\site-packages\IPython\core\interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\chano\AppData\Local\Temp\ipykernel_20684\3882431777.py", line 12, in <module>
#     Y = keras.utils.to_categorical(Y, num_classes)
#   File "D:\Users\chano\Anaconda2\envs\tf-gpu\lib\site-packages\keras\utils\np_utils.py", line 25, in to_categorical
#     y = np.array(y, dtype='int')
# ...

# %%
import yaml
import pandas as pd
with open('train.yaml', 'r') as f:
    df = pd.io.json.json_normalize(yaml.load(f, Loader=yaml.FullLoader),'boxes', 'path' )



    

i = 0
k = 1
a = 5093-1 # is number of images in folders
while df.shape[0] >= 5092:
    if ((df['path'][i]) == (df['path'][k])):
        if ((df['x_max'][i]-df['x_min'][i])*(df['y_max'][i]-df['y_min'][i])) >=  ((df['x_max'][k]-df['x_min'][k])*(df['y_max'][k]-df['y_min'][k])):
            df.drop(k, inplace = True)
            #a = a - 1
            k = k+1
            continue
        else :
            df.drop(i, inplace = True)
            #a = a - 1
            i = k
            k = i+1
            continue          
    else: 
        i = k
        k = i+1
        continue
        

        
import numpy as np
from skimage import color, exposure, transform 
import  skimage
from skimage.color import rgb2gray
from skimage.filters import sobel_h
import skimage.color
import skimage.filters
from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Activation, Flatten
from keras.layers.convolutional import Conv2D
from keras.layers.pooling import MaxPooling2D
from keras.optimizers import SGD
from keras import backend as K
K.set_image_data_format('channels_first')
from skimage.transform import rescale

from matplotlib.pyplot import figure, show
from sklearn.model_selection import train_test_split
import pandas as pd
import os
import numpy as np
from sklearn import metrics
from scipy.stats import zscore
import tensorflow as tf
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint    




def preprocess_img(img):

    #img = rgb2gray(img)
    
    # thresholding and sobel filter
    #t = skimage.filters.threshold_otsu(img)
    #img = img > t

    #img = sobel_h(img)
    
    # top half crop
    #img = img[240:480,0:640]

    # downsample by 100
    img = rescale(img, scale=(0.1))
    
    # roll color to axis 0
    img = np.rollaxis(img, -1)

    return img





from skimage import io
import os
import glob




root_dir = 'dataset_train_riib/riib/train/'
imgs = []
labels = []

all_img_paths = glob.glob(os.path.join(root_dir, '*/*.pgm'))
i = 0
#np.random.shuffle(all_img_paths)
for img_path in all_img_paths:
    img = preprocess_img(io.imread(img_path))
    a = df.index[i] 
    i = i + 1
    label = df['label'][a]
    imgs.append(img)
    labels.append(label)


X = np.array(imgs, dtype='float32')
# Make one hot targets
Y = labels


from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Activation, Flatten
from keras.layers.convolutional import Conv2D
from keras.layers.pooling import MaxPooling2D
from keras.optimizers import SGD
from keras import backend as K
K.set_image_data_format('channels_first')


def cnn_model():
    model = Sequential()

    model.add(Conv2D(32, (3, 3), padding='same',
                     activation='relu'))
    model.add(Conv2D(32, (3, 3), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.2))

    model.add(Conv2D(64, (3, 3), padding='same',
                     activation='relu'))
    model.add(Conv2D(64, (3, 3), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.2))

    model.add(Conv2D(128, (3, 3), padding='same',
                     activation='relu'))
    model.add(Conv2D(128, (3, 3), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.2))

    model.add(Flatten())
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(6, activation='softmax'))
    return model


from keras.optimizers import SGD

model = cnn_model()

# let's train the model using SGD + momentum
lr = 0.01
sgd = SGD(lr=lr, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy',
              optimizer=sgd,
              metrics=['accuracy'])



pred = model.predict(X_test)
pred = np.argmax(pred,axis=1)
score = metrics.accuracy_score(Y_test, pred)
print('Accuracy: {}'.format(score))
